# %% [markdown]
# ## Práctica Algoritmo de Dijkstra

# %% [markdown]
# ALUMNOS:
# - Agustín Prieto
# - Jesús Sanz
#
#
#
#
#
# Nota: Obligatorio completar los autores

# %% [markdown]
# El algoritmo de Dijkstra es una técnica voraz que permite encontrar el camino más entre dos nodos de un grafo dirigido
# ponderado con pesos positivos.
#
# En esta práctica se implementará este algoritmo, así como algunas variantes y mejoras, para el cálculo de caminos en un
# espacio euclídeo de dos dimensiones. En concreto, se dispone de la información relativa a la ubicación de un conjunto de
# ciudades y a las carreteras que transcurren entre ellas, y se ha de calcular el camino más rápido para viajar desde una
# a otra.
#
# Para el desarrollo de la práctica se contará con un conjunto de clases escritas en Python, y que permiten leer la
# información de los mapas, llevar a cabo funciones de visualización, e interaccionar con los algoritmos.
#
# Además, se proporciona el esqueleto de las dos clases en las que se han de implementar los algoritmos y el diccionario
# de prioridad. De este modo, el trabajo de programación se reduce a la implementación de estas clases.

# %% [markdown]
# En esta celda hacemos uso de los paquetes. La primera es posible que sea necesario descomentar las tres primeras líneas
# para instalar los tres paquetes necesarios.

# %%
#!pip install folium
#!pip install geopy
#!pip install panda

# pip solo se hace una vez para cada libreria

import folium
# Para dibujar el mapa de salida
import geopy
# Para calcular distancia euclídea
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
app = Nominatim(user_agent="tycgis")
from folium.plugins import MiniMap
# import requests module 
import requests
import ipywidgets as widgets
import time
import os
import pandas as pd
from time import time
import numpy as np

# %% [markdown]
# Establecemos la estructura de datos de ciudades, dividida en capitales de provincia, que se imprimirán en el mapa, y resto
# de poblaciones, que no se visualizarán.
# Para cada una de ellas disponemos de sus coordenadas geográficas. Solo se ponen las ubicadas en la península ibérica,
# accesibles por carretera.

# %%
pueblos = {
 'Adra': (36.75932403011123, -2.9959979099413623),
 'Abrantes': (39.4631905, -8.1973618),
 'Adanero': (40.9438737, -4.6038249),
 'Ágreda': (41.8548465, -1.9214614),
 'Aguilar de Campoó': (42.7928369, -4.2605438),
 'Alacant': (38.3436365, -0.4881708),
 'Albocàsser': (40.3571915, 0.0245058),
 'Albufeira': (37.088241, -8.2526339),
 'Alcalá de Henares': (40.4818396, -3.3644973),
 'Alcance': (39.2535359, -1.0961698),
 'Alcantarilla': (37.9680342, -1.214954),
 'Alcañices': (41.6996962, -6.3471637),
 'Alcañiz': (41.0505393, -0.1307197),
 'Alcaraz': (38.6647483, -2.4910801),
 'Alcolea del Pinar': (41.0359238, -2.4673489),
 'Alcoy': (38.6982275, -0.4747767),
 'Alfaro': (42.1785741, -1.7492454),
 'Algeciras': (36.1311725, -5.4473991),
 'Almadén': (38.7742489, -4.832835),
 'Almadrones': (40.9012507, -2.7737105),
 'Almansa': (38.8682065, -1.0978627),
 'Almazán': (41.4870645, -2.5335988),
 'Almonte': (37.2611686, -6.5175751),
 'Almuñecar': (36.7328699, -3.68968),
 'Alzira': (39.151212, -0.4346556),
 'Amposta': (40.7079905, 0.5827636),
 'Andújar': (38.0392362, -4.0505603),
 'Ansiao': (39.9113771, -8.4359857),
 'Antequera': (37.0183652, -4.5596649),
 'Aranda de Duero': (41.6715067, -3.6851172),
 'Aranjuez': (40.03221, -3.6039604),
 'Arenas de San Pedro': (40.2107266, -5.0868775),
 'Arévalo': (41.0632758, -4.7198921),
 'Arganda del Rey': (40.3007708, -3.4380688),
 'Armiñón': (42.722587, -2.8722115),
 'Arzúa': (42.92374955, -8.15281746981209),
 'Astorga': (42.4553555, -6.0529025),
 'Aveiro': (40.640496, -8.6537841),
 'Avilés': (43.5554436, -5.9222466),
 'Ayamonte': (37.215797, -7.4060169),
 'Ayora': (39.0596612, -1.057216),
 'Baamonde': (43.1395946, -7.5390136),
 'Baena': (37.6173035, -4.324371),
 'Bailén': (38.096787, -3.7765601),
 'Barbastro': (42.034453, 0.1264012),
 'Barreiros': (43.535368982783446, -7.24283944475006),
 'Basauri': (43.235372, -2.8920543),
 'Baza': (37.4888637, -2.7709805),
 'Becerrea': (42.8544959, -7.1616043),
 'Beja': (38.0154479, -7.8650368),
 'Béjar': (40.3865812, -5.7649619),
 'Belmonte': (39.5592831, -2.7038117),
 'Benabarre': (42.1063137, 0.4820182),
 'Benavente': (42.0032862, -5.6738595),
 'Benicarló': (40.4180244, 0.4229813),
 'Benicàssim': (40.0554964, 0.0644165),
 'Benidorm': (38.5406255, -0.1290929),
 'Betanzos': (43.2757359, -8.23264173925292),
 'Bicorp': (39.1323971, -0.7877353),
 'Boltaña': (42.4457355, 0.0680185),
 'Borriol': (40.0422215, -0.0714919),
 'Braga': (41.5510583, -8.4280045),
 'Bragança': (41.5084468, -6.773302360533066),
 'Burgo de Osma': (41.5868712, -3.0674254),
 'Calatayud': (41.3527628, -1.6422977),
 'Caldas da Rainha': (39.4071857, -9.1346004),
 'Callosa del Segura': (38.3460486, -0.4944558),
 'Campillos': (37.0470137, -4.8621698),
 'Campomanes': (43.1054181, -5.8185558),
 'Cangas de Onís': (43.3136138, -5.065850290011571),
 'Cañete': (40.041797, -1.6490269),
 'Carballo': (43.2134123, -8.6891286),
 'Carboneras': (36.9968699, -1.8946552),
 'Carregado': (39.0055219, -8.9537297),
 'Cartagena': (37.60675362409654, -0.9841418509354086),
 'Casas Ibáñez': (39.2869161, -1.4706566),
 'Casa de Juan Gil': (39.126944, -1.2425),
 'Cascais': (38.6968919, -9.4204495),
 'Caspe': (41.2368564, -0.0394889),
 'Castelldefels': (41.2861022, 1.9824173),
 'Castelo Branco': (39.97675825, -7.446059929966704),
 'Castro Urdiales': (43.3843347, -3.2162576),
 'Caudete': (38.706703, -0.9867978),
 'Cerceda': (43.08523156594481, -3.4486988299225527),
 'Cervera': (41.670378400000004, 1.2680142494341275),
 'Chantada': (42.61090765, -7.810749170573104),
 'Chiclana de la Frontera': (36.4191096, -6.1460683),
 'Chiva': (39.4726098, -0.7178348),
 'Cieza': (38.2479256153942, -1.4182315889989041),
 'Cinctorres': (40.5825853, -0.2161136),
 'Cistierna': (42.8031437, -5.1255957),
 'Cocentaina': (38.744158, -0.4400707),
 'Coimbra': (40.2111931, -8.4294632),
 'Collado Villalba': (40.6431496, -3.9930128),
 'Coruche': (38.958218, -8.5283498),
 'Covilha': (40.2804021, -7.504191),
 'Cudillero': (43.54335745, -6.1936313237885),
 'Cullera': (39.1647217, -0.2542313),
 'Daimiel': (39.072196, -3.6143611),
 'Daroca': (41.1133264, -1.4170637),
 'Dos Hermanas': (37.283689, -5.9226718),
 'Durango': (43.17773905907672, -2.6240870550508753),
 'Durcal': (36.9879333, -3.5663828),
 'Écija': (37.5406007, -5.079589),
 'El Barco de Ávila': (40.3577409, -5.5231241),
 'El Burgo del Ebro': (41.5599303, -0.7204564),
 'Elda': (38.4789671, -0.7956759),
 'Elvas': (38.8806123, -7.1637237),
 'Elx': (38.2653307, -0.6988391),
 'Espiel': (38.1885533, -5.0189717),
 'Espinho': (41.0083643, -8.6394111),
 'Estepa': (37.29204, -4.8781876),
 'Estepona': (36.4268068, -5.1468484),
 'Estremoz': (38.8432944, -7.586907),
 'Évora': (38.5707742, -7.9092808),
 'Faro': (37.0162727, -7.9351771),
 'Feira': (40.9316799, -8.552306217314651),
 'Ferrol': (43.4846862, -8.233162),
 'Figueira da Foz': (40.1485808, -8.855655),
 'Figueres': (42.2666314, 2.9638434),
 'Fraga': (41.5221304, 0.3501756),
 'Fuengirola': (36.5388398, -4.6233974),
 'Gaia': (41.122811404202224, -8.616241437568595),
 'Gandia': (38.9675925, -0.1803423),
 'Gibraleón': (37.3746324, -6.9690748),
 'Gijón': (43.53819155356016, -5.665131371077161),
 'Gimileo': (42.5494612, -2.8229957),
 'Grado': (43.386210140855724, -6.074232865258658),
 'Grândula': (38.1790, -8.5648164),
 'Graus': (42.189949, 0.3389797),    
 'Grao de Sagunt': (39.64670082183546, -0.2853007827378621),
 'Guadiaro': (36.300318, -5.301881),
 'Guarda': (40.7046066, -7.195139236071309),
 'Guardamar del Segura': (38.0899985, -0.65381),
 'Guntín': (42.90121465, -7.657714434445812),
 'Hellín': (38.5106649, -1.6995137),
 'Herrera del Duque': (39.1676109, -5.0504659),
 'Híjar': (41.1747377, -0.4515985),
 'Honrubia': (39.613532, -2.2807538),
 'Ibi': (38.623288, -0.5730513),
 'Igualada': (41.5790182, 1.617346),
 'Izurzun': (43.31449706566802, -2.002465215572012),
 'Jabugo': (37.9168052, -6.7291607),
 'Jaca': (42.5692515, -0.549372),
 'Jerez de la Frontera': (36.681727, -6.139157),   
 'La Albuera': (38.7172283, -6.8230848),
 'La Bañeza': (42.2998096, -5.8970081),
 'La Espina': (43.2647914, -3.3880441),
 'Lagos': (37.136773214712676, -8.688351586068762),
 'La Jonquera': (42.4207991, 2.8728485),
 "L'Alcora": (40.0744223, -0.2138589),
 'Lalín': (42.6614127, -8.1109759),
 'La Línea de la Concepción': (36.1677899, -5.3482396),
 'La Magdalena': (42.78535541199772, -5.799146099403363),
 'Laredo': (43.40694714305638, -3.4165607026463864),
 'La Roda': (39.20702, -2.1581637),
 "La Seu d'Urgell": (42.3575723, 1.4560067),
 'La Unión': (37.6219632, -0.8827593),
 'Leiria': (39.7437902, -8.8071119),
 'León': (42.63414505, -5.971415104539984),
 'Lepe': (37.2551712, -7.201556),
 'Lerma': (42.0262334, -3.7559335),
 'Les Borges Blanques': (41.5203322, 0.8684098),
 "L'Hospitalet de l'Infant": (40.9930816, 0.9226161),
 'Linares': (38.0931247, -3.6357609),
 'Liria': (39.6251478, -0.5952749),
 'Llanes': (43.4211205, -4.7530835),
 'Llerena': (38.2378976, -6.0149901),
 'Llivia': (42.4640786, 1.9804293),
 'Loja': (37.1664839, -4.1496374),
 'Lorca': (37.6712139, -1.6990431),
 'Losa del Obispo': (39.695763, -0.8710594),
 'Los Alcázares': (37.7466009, -0.8556533),
 'Los Gallardos': (37.1675863, -1.9394052),
 'Luarca': (43.5439003, -6.5357408),
 'Lucena': (37.4091334, -4.4860128),
 'Lugo': (43.0396042, -7.456607166509571),
 'Macedo de Cavaleiros': (41.5362124, -6.9560267),
 'Madridejos': (39.4708879, -3.5355038),
 'Manresa': (41.7288939, 1.8286765),
 'Mansilla de la Mulas': (42.497603, -5.415263),   
 'Manzanares': (38.9962242, -3.3722143),
 'Maqueda': (40.06533, -4.3720335),
 'Marbella': (36.508976, -4.88562),
 'Marín': (42.3922393, -8.7029421),
 'Mataró': (41.5398348, 2.4448926),
 'Mazagón': (37.14597, -6.8562644),
 'Medinaceli': (41.1723392, -2.4353741),
 'Medina del Campo': (41.3085496, -4.9150256),
 'Mérida': (38.9174665, -6.3443977),
 'Mieres': (43.2488161, -5.7722468),
 'Miranda del Ebro': (42.788628, -3.3641992),
 'Mogadouro': (41.3418708, -6.7121674),
 'Molina de Aragón': (40.8491293, -1.8813995592876256),
 'Mombuey': (42.0226242, -6.3311768),
 'Monforte de Lemos': (42.5236693, -7.5096951),
 'Monóvar': (38.4387815, -0.8396316),
 'Monreal del Campo': (40.7896541, -1.3529881),
 'Montalbán': (40.8405106, -0.7945674618382108),
 'Montemor-o-Novo': (38.6481777, -8.2115858),
 'Montijo': (38.9098936, -6.6151799),
 'Montoro': (38.0215633, -4.3827296),
 'Monzón': (41.9143981, 0.1922412),
 'Morella': (40.6188277, -0.0998026),
 'Motril': (36.7450888, -3.5207655),
 'Murça': (41.42591455, -7.465569503607106),
 'Navalmoral de la Mata': (39.8928306, -5.5401199),
 'Navia': (43.5391112, -6.7233704),
 'Novelda': (38.3842144, -0.7674146),
 'Nueno': (42.2665821, -0.4393139),
 'Nules': (39.8532265, -0.1550092),
 'O Barco': (42.416462, -6.9843044),
 'Ocaña': (39.9586665, -3.5007717),
 'Odemira': (37.5976, -8.6422),
 'Oitura': (41.729177, -1.1932591),
 'Oliva': (38.9202443, -0.1208981),
 'Olot': (42.1822177, 2.4890211),
 'Onda': (39.9621514, -0.2593846),
 'Ontinyent': (38.8208523, -0.6099929),
 'Osorno': (42.4106725, -4.3609815),
 'Ourique': (37.651112, -8.2237262),
 'Padul': (37.0222913, -3.6274938),
 'Peniche': (39.3568749, -9.3786838),
 'Peñafiel': (41.5975136, -4.1227931),
 'Peñaranda de Bracamonte': (40.9024602, -5.2006416),
 'Peñíscola': (40.3576361, 0.4071043),
 'Piedrabuena': (39.0344592, -4.1753284),
 'Pinoso': (38.4021056, -1.041617),
 'Plasencia': (40.029921, -6.090168),
 'Pola de Siero': (43.3914146, -5.6608367),
 'Ponferrada': (42.5454124, -6.5938719),
 'Pont de Suert': (42.4079576, 0.7401693),
 'Ponteareas': (42.17561317640825, -8.5069639563138),    
 'Ponte de Lima': (41.7675021, -8.5830992),
 'Pontedeume': (43.4072585, -8.1718823),
 'Ponte do Sôr': (39.24832855, -8.012372917228461),
 'Portalegre': (39.2076447, -7.721513354015343),
 'Portbou': (42.4274333, 3.1588785),
 'Portman': (37.5911824, -0.8527408),
 'Porto': (41.1494512, -8.6107884),
 'Potes': (43.1536831, -4.623428),
 'Puertollano': (38.6852161, -4.1111749),
 'Puerto Lumbreras': (37.5635045, -1.8076233),
 'Puerto Real': (36.5286856, -6.1902161),
 'Puigcerdà': (42.4317966, 1.9278693),
 'Quintana del Puente': (42.0841001, -4.2074696),
 'Quintanilha': (41.7514181, -6.5700521),
 'Reinosa': (43.0010076, -4.1378363),
 'Requena': (39.4880777, -1.1001643),
 'Reus': (41.1555564, 1.1076133),
 'Riaza': (41.279379, -3.4772594),
 'Ribadavia': (42.2880044, -8.1429521),
 'Ribadeo': (43.5361589, -7.0436775),
 'Ribadesella': (43.4617129, -5.0587479),
 'Ribeira de Pena': (41.5217103, -7.795143),
 'Rincón de la Victorio': (36.718641739895496, -4.279642488207788),
 'Ripoll': (42.1982391, 2.1932496),
 'Ronda': (36.7421339, -5.1665916),
 'Ruidera': (38.977123, -2.8838992),
 'Sabiñánigo': (42.518364, -0.3647899),
 'Sacedón': (40.481085, -2.732881),
 'Sagunt': (39.6792916, -0.2786451),
 'Salamanca': (40.9651572, -5.6640182),
 'San Ciprián': (43.68631022379616, -7.459260592653653),
 'San Esteban de Gormaz': (41.574307, -3.2041516),
 'San Fernando': (36.4646672, -6.1983492),
 'San Rafael': (40.716319670498976, -4.1867767817737995),
 'Santa Pola': (38.1923641, -0.5555464),
 'Santarem': (39.2850041, -8.556447653068235),
 'Santiago de Compostela': (42.90645755, -8.51929826271505),
 "Sant Joan d'Alacant": (38.4014162, -0.4359957),
 'Santo Domingo de la Calzada': (42.4406711, -2.9536395),
 'Segorbe': (39.8519011, -0.4895537),
 'Serpa': (37.9436517, -7.5966902),
 'Setubal': (38.5241783, -8.8932341),
 'Silla': (39.3632045, -0.4112618),
 'Sines': (37.956549, -8.8689639),
 'Sintra': (38.79846, -9.3881),
 'Sitges': (41.2366707, 1.8228136),
 'Solares': (43.388846603816816, -3.7336059424529973),
 'Soria': (41.60125045, -2.721938035449954),
 'Sueca': (39.2025604, -0.3111645),
 'Tafalla': (42.5278279, -1.6744823),
 'Talavera de la Reina': (39.9603798, -4.8311717),
 'Tarancón': (40.0086075, -3.0102243),
 'Tarazona': (41.9065093, -1.7216461),
 'Tarifa': (36.0129082, -5.6050213),
 'Tavira': (37.1262493, -7.6499121),
 'Tordesillas': (41.500851, -5.00053),
 'Toro': (41.5216963, -5.3939824),
 'Torreblanca': (40.2202661, 0.1953363),
 'Torrelavega': (43.3487303, -4.0515082),
 'Torremolinos': (36.6242841, -4.4995448),
 'Torres Novas': (39.47962, -8.53955),
 'Torres Vedras': (39.0930856, -9.260741),
 'Torrevieja': (37.9775416, -0.6828446),
 'Totana': (37.7697645, -1.5025376),
 'Trujillo': (39.4605657, -5.8816626),
 'Tuj': (42.16978724230882, -8.62101807343588),
 'Úbeda': (38.0111494, -3.3718691),
 'Unquera': (43.3745998, -4.5145487),
 'Utiel': (39.5680838, -1.2051778),
 'Valdepeñas': (38.7594573, -3.3847392),
 'Valencia de Alcántara': (39.4131571, -7.2420859),
 'Valongo': (41.1909794, -8.4980511),
 'Valverde del Camino': (37.5739612, -6.7543559),
 'Vegadeo': (43.4153116, -6.999106571661519),
 'Vélez-Rubio': (37.6482765, -2.0745368),
 'Venta El Alto': (37.64697773887377, -6.157891419544876),
 'Venturada': (40.7985257, -3.6207369),
 'Vera': (37.2475942, -1.8681961),
 'Verín': (41.9406091, -7.4406032),
 'Viana do Castelo': (41.70416246220342, -8.809209172248952),    
 'Vic': (41.9302021, 2.2545943),
 'Vigo': (42.22388541452606, -8.729649369512089),    
 'Vielha': (42.7017572, 0.7954744),
 'Vila Flor': (41.3067941, -7.1517712),
 'Vilafranca del Cid': (40.4270485, -0.2577628),
 'Vilafranca del Penedés': (41.3463825, 1.6995213),
 'Vilagarcía de Arousa': (42.5947625, -8.7669178),
 'Vila Nova de Foz Côa': (41.0818397, -7.1424138),
 'Vila-real': (39.9372616, -0.1004465),
 'Vila Real': (41.278532346079366, -7.724376282447581),
 'Vilareal de Santo Antonio': (37.19302859757792, -7.424496347410952),    
 'Villalón de Campos': (42.0984494, -5.0347132),
 'Villarrobledo': (39.2681742, -2.6042132),
 'Villena': (38.6360967, -0.8659745),
 'Vinarós': (40.4703992, 0.4746076),
 'Viseu': (40.6574713, -7.9138664),
 'Xàtiva': (38.9880871, -0.5200052),
 'Xert': (40.5186118, 0.1585541),
 'Xinzo de Limia': (42.0637882, -7.7245498),
 'Yecla': (38.6135956, -1.1157882),
 'Zafra': (38.4253489, -6.4193627),
 'Zarauz': (43.2834873, -2.1723467),
 'Zuera': (41.8659094, -0.7886383)}
tam1 = len(pueblos)

# %%
import geopy.distance


geopy.distance.distance((39.9603798, -4.8311717),(38.6135956, -1.1157882)).km+1
# Out:
# 354.6632969382138

# %%
ciudades = {
    'A Coruña' : (43.37012643, -8.39114853),
    'Albacete' : (38.99588053, -1.85574745),
    'Alicante' : (38.34548705, -0.4831832),
    'Almería' : (36.83892362, -2.46413188),
    'Ávila' : (40.65586958, -4.69771277),
    'Badajoz' : (38.87874339, -6.97099704),
    'Barcelona' : (41.38424664, 2.17634927),
    'Bilbao' : (43.25721957, -2.92390606),
    'Burgos' : (42.34113004, -3.70419805),
    'Cáceres' : (39.47316762, -6.37121092),
    'Cádiz' : (36.52171152, -6.28414575),
    'Castelló de la Plana' : (39.98640809, -0.03688142),
    # 'Ceuta' : (35.88810209, -5.30675127),
    'Ciudad Real' : (38.98651781, -3.93131981),
    'Córdoba' : (37.87954225, -4.78032455),
    'Cuenca' : (40.07653762, -2.13152306),
    'Donostia' : (43.31924454673363, -1.9832245902526295),
    'Girona' : (41.98186075, 2.82411899),
    'Granada' : (37.17641932, -3.60001883),
    'Guadalajara' : (40.63435548, -3.16210273),
    'Huelva' : (37.26004113, -6.95040588),
    'Huesca' : (42.14062739, -0.40842276),
    'Jaén' : (37.7651913, -3.7903594),
    # 'Las Palmas' : (28.09937855, -15.41336841),
    'León' : (42.59912097, -5.56707631),
    'Lisboa' : (38.72457546504939, -9.149236171829303),    
    'Lleida' : (41.61527355, 0.62061934),
    'Logroño' : (42.46644945, -2.44565538),
    'Lugo' : (43.0091282, -7.55817392),
    'Madrid' : (40.40841191, -3.68760088),
    'Málaga' : (36.72034267, -4.41997511),
    #'Melilla' : (35.294731, -2.942281),
    'Murcia' : (37.98436361, -1.1285408),
    'Ourense' : (42.33654919, -7.86368375),
    'Oviedo' : (43.36232165, -5.84372206),
    'Palencia' : (42.0078373, -4.53460106),
    #'Illes Balears' : (39.57114699, 2.65181698),
    'Pamplona' : (42.814102, -1.6451528),
    'Pontevedra' : (42.43381442, -8.64799018),
    'Salamanca' : (40.96736822, -5.66538084),
    'Gipuzkoa' : (43.31717158, -1.98191785),
    #'Santa Cruz de Tenerife' : (28.46285408, -16.24720629),
    'Santander' : (43.46297885, -3.80474784),
    'Segovia' : (40.9498703, -4.12524116),
    'Sevilla' : (37.38620512, -5.99251368),
    'Soria' : (41.76327912, -2.46624798),
    'Tarragona' : (41.11910287, 1.2584219),
    'Teruel' : (40.34412951, -1.10927177),
    'Toledo' : (39.85715187, -4.02431421),
    'Valencia' : (39.47534441, -0.37565717),
    'Valladolid' : (41.65232777, -4.72334924),
    'Vitoria' : (42.85058789, -2.67275685),
    'Zamora' : (41.49913956, -5.75494831),
    'Zaragoza' : (41.65645655, -0.87928652),

}
tam = len(ciudades)

# Hacemos una copia de las capitales
capitales = {}
for c in ciudades:
    capitales[c] = ciudades[c]

# Sumamos latitudes y longitudes para ajustar en el mapa con la media
lat = 0
long = 0
for i in ciudades:
    lat += ciudades[i][0]
    long += ciudades[i][1]

# %%
#
# Cálculo de la distancia euclídea, a efectos ilustrativos
# Procedente del paquete GeoPy
#
distancia = geodesic((ciudades['Albacete'][0], ciudades['Albacete'][1]), (ciudades['Madrid'][0], ciudades['Madrid'][1]))

# Ejemplo de uso
# La distancia es una información estructurada, para obtenerlo en formato numérico hay que especificar en kilómetros

print(distancia)
print(distancia.kilometers)

# La documentación puede consultarse en https://geopy.readthedocs.io/en/stable/
# Out:
# 221.9774818778376 km
# 221.9774818778376

# %%
#
#  El fichero carreteras.txt debe establecerse con el path correspondiente a la ubicación en cada práctica
#
#file_path = "C:\\Users\Fernando.Cuartero\OneDrive - Universidad de Castilla-La Mancha\\DA\\DA\\PRÁCTICAS ACT\\Dijkstra2024\\carreteras.txt"
file_path = 'C:\\practicas_diseno_de_algoritmos_con_jesus\\practicas_diseno_de_algoritmos\\Práctica2\\carreteras.txt'

data = pd.read_csv(file_path, delimiter = "\t")
dicCarreteras = {}
for row in data.itertuples():
    sp = row._1.split(':')
    dicCarreteras[(sp[0],sp[1])] = float(sp[2])

# %%
#
#  El fichero autovias.txt debe establecerse con el path correspondiente a la ubicación en cada práctica
#
#file_path = "C:\\Users\Fernando.Cuartero\OneDrive - Universidad de Castilla-La Mancha\\DA\\DA\\PRÁCTICAS ACT\\Dijkstra2024\\autovias.txt"
file_path = 'C:\\practicas_diseno_de_algoritmos_con_jesus\\practicas_diseno_de_algoritmos\\Práctica2\\autovias.txt'
data = pd.read_csv(file_path, delimiter = "\t")
dicAutovias = {}
for row in data.itertuples():
    sp = row._1.split(':')
    dicAutovias[(sp[0],sp[1])] = float(sp[2])

# %% [markdown]
# En la siguiente celda establecemos el mapa, haciendo uso del paquete folium previamente importado.
# Finaliza mostrando el resultado.

# %%
salida = folium.Map(location = [lat/tam, long/tam], zoom_start=6)
for i in ciudades:
    folium.Marker(
        location=[ciudades[i][0] , ciudades[i][1]],
        #icon=folium.Icon(color = 'red'),
        icon=folium.DivIcon(html=f"""
            <div><svg>
                <rect x="0", y="0" width="5" height="5", fill="black", opacity=".5" />
            </svg></div>"""),
            #<circle cx="0" cy="0" r="10" fill="#red" opacity=".5"/>
        popup=''
    ).add_to(salida)
    
    
salida
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6feef8338a812e4ef0b8aa8a4cc181d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6feef8338a812e4ef0b8aa8a4cc181d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6feef8338a812e4ef0b8aa8a4cc181d2 = L.map(
#                 &quot;map_6feef8338a812e4ef0b8aa8a4cc181d2&quot;,
#                 {
#                     center: [40.61331950370985, -3.5532346331037137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a10a43bd6f18f9a7136fcf239ba30e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a10a43bd6f18f9a7136fcf239ba30e5.addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var marker_8d2a30ea73b0fb2a9cc36bde981b6481 = L.marker(
#                 [43.37012643, -8.39114853],
#                 {
# }
#             ).addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var div_icon_cdec393e9078f11341b004bf5c11925b = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_8d2a30ea73b0fb2a9cc36bde981b6481.setIcon(div_icon_cdec393e9078f11341b004bf5c11925b);
#
#
#         var popup_6829f4dfe66c05f3f1a1299557b2de51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f28dc8d9b2d1e4b08ca9ac57d0fef0 = $(`&lt;div id=&quot;html_01f28dc8d9b2d1e4b08ca9ac57d0fef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_6829f4dfe66c05f3f1a1299557b2de51.setContent(html_01f28dc8d9b2d1e4b08ca9ac57d0fef0);
#
#
#
#         marker_8d2a30ea73b0fb2a9cc36bde981b6481.bindPopup(popup_6829f4dfe66c05f3f1a1299557b2de51)
#         ;
#
#
#
#
#                 marker_8d2a30ea73b0fb2a9cc36bde981b6481.setIcon(div_icon_cdec393e9078f11341b004bf5c11925b);
#
#
#             var marker_d5dd46170b5a7e3a0b6ea0e039058b40 = L.marker(
#                 [38.99588053, -1.85574745],
#                 {
# }
#             ).addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var div_icon_7c320ad1a243d10151cea00ea045642e = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_d5dd46170b5a7e3a0b6ea0e039058b40.setIcon(div_icon_7c320ad1a243d10151cea00ea045642e);
#
#
#         var popup_0ed30024c2d89a964f9792ba2633a602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_683bd27ccb549967b2f652df52793d19 = $(`&lt;div id=&quot;html_683bd27ccb549967b2f652df52793d19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_0ed30024c2d89a964f9792ba2633a602.setContent(html_683bd27ccb549967b2f652df52793d19);
#
#
#
#         marker_d5dd46170b5a7e3a0b6ea0e039058b40.bindPopup(popup_0ed30024c2d89a964f9792ba2633a602)
#         ;
#
#
#
#
#                 marker_d5dd46170b5a7e3a0b6ea0e039058b40.setIcon(div_icon_7c320ad1a243d10151cea00ea045642e);
#
#
#             var marker_4909c7bfdd60322528ac8c62afa7212f = L.marker(
#                 [38.34548705, -0.4831832],
#                 {
# }
#             ).addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var div_icon_d02f64a39eb65b0a87f8fb3349bda692 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4909c7bfdd60322528ac8c62afa7212f.setIcon(div_icon_d02f64a39eb65b0a87f8fb3349bda692);
#
#
#         var popup_0dab4640d17dfce9d290c711cf91f38e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3698758564904b3c98e49ee7474b3cf2 = $(`&lt;div id=&quot;html_3698758564904b3c98e49ee7474b3cf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_0dab4640d17dfce9d290c711cf91f38e.setContent(html_3698758564904b3c98e49ee7474b3cf2);
#
#
#
#         ma

# %% [markdown]
# Se construye el grafo con las distancias.
#
# dist[(o,d)] indica la distancia entre o (origen) y d (destino).
#
# Es un diccionario donde cada elemento clave es un par de ciudades.

# %%
# Preparar el grafo

dist = {}
#Creamos un nuevo diccionario unión de los otros dos
ciudades.update(pueblos)
nodos = len(ciudades)
for i in ciudades:
    for j in ciudades:
        elem = (i, j)
        if elem in dicCarreteras.keys():
            dist[elem]  = dicCarreteras[elem]/90
            dist[(j,i)] = dicCarreteras[elem]/90
            # Los tramos de carreteras los consideramos a 90 km/h
        elif elem in dicAutovias.keys():
            dist[elem]  = dicAutovias[elem]/120
            dist[(j,i)] = dicAutovias[elem]/120     
            # Los tramos de autovía los consideramos a 120 km/h

# %%
dist
# Out:
# {('A Coruña', 'Pontedeume'): 0.23226666666666668,
#  ('Pontedeume', 'A Coruña'): 0.23226666666666668,
#  ('Albacete', 'Almansa'): 0.47714166666666663,
#  ('Almansa', 'Albacete'): 0.47714166666666663,
#  ('Albacete', 'Ruidera'): 0.8611555555555556,
#  ('Ruidera', 'Albacete'): 0.8611555555555556,
#  ('Albacete', 'Tarancón'): 0.7366666666666667,
#  ('Tarancón', 'Albacete'): 0.7366666666666667,
#  ('Almería', 'Adra'): 0.3484,
#  ('Adra', 'Almería'): 0.3484,
#  ('Ávila', 'Adanero'): 0.39470000000000005,
#  ('Adanero', 'Ávila'): 0.39470000000000005,
#  ('Ávila', 'Arenas de San Pedro'): 0.38695555555555555,
#  ('Arenas de San Pedro', 'Ávila'): 0.38695555555555555,
#  ('Ávila', 'Arévalo'): 0.6004444444444444,
#  ('Arévalo', 'Ávila'): 0.6004444444444444,
#  ('Ávila', 'Maqueda'): 0.5675444444444444,
#  ('Maqueda', 'Ávila'): 0.5675444444444444,
#  ('Ávila', 'Peñaranda de Bracamonte'): 0.5402222222222222,
#  ('Peñaranda de Bracamonte', 'Ávila'): 0.5402222222222222,
#  ('Ávila', 'San Rafael'): 0.46707777777777776,
#  ('San Rafael', 'Ávila'): 0.46707777777777776,
#  ('Badajoz', 'Mérida'): 0.41811666666666664,
#  ('Mérida', 'Badajoz'): 0.41811666666666664,
#  ('Barcelona', 'Igualada'): 0.4352888888888889,
#  ('Igualada', 'Barcelona'): 0.4352888888888889,
#  ('Barcelona', 'Manresa'): 0.6021888888888889,
#  ('Manresa', 'Barcelona'): 0.6021888888888889,
#  ('Barcelona', 'Mataró'): 0.16368333333333332,
#  ('Mataró', 'Barcelona'): 0.16368333333333332,
#  ('Barcelona', 'Vic'): 0.6173000000000001,
#  ('Vic', 'Barcelona'): 0.6173000000000001,
#  ('Barcelona', 'Vilafranca del Penedés'): 0.40846666666666664,
#  ('Vilafranca del Penedés', 'Barcelona'): 0.40846666666666664,
#  ('Bilbao', 'Castro Urdiales'): 0.2052,
#  ('Castro Urdiales', 'Bilbao'): 0.2052,
#  ('Burgos', 'Palencia'): 0.8343,
#  ('Palencia', 'Burgos'): 0.8343,
#  ('Burgos', 'Lerma'): 0.26766666666666666,
#  ('Lerma', 'Burgos'): 0.26766666666666666,
#  ('Burgos', 'Quintana del Puente'): 0.5421666666666667,
#  ('Quintana del Puente', 'Burgos'): 0.5421666666666667,
#  ('Cáceres', 'Plasencia'): 0.5304749999999999,
#  ('Plasencia', 'Cáceres'): 0.5304749999999999,
#  ('Cáceres', 'Trujillo'): 0.5031555555555556,
#  ('Trujillo', 'Cáceres'): 0.5031555555555556,
#  ('Cáceres', 'Valencia de Alcántara'): 0.7167222222222221,
#  ('Valencia de Alcántara', 'Cáceres'): 0.7167222222222221,
#  ('Castelló de la Plana', 'Borriol'): 0.07254444444444444,
#  ('Borriol', 'Castelló de la Plana'): 0.07254444444444444,
#  ('Castelló de la Plana', 'Sagunt'): 0.43333333333333335,
#  ('Sagunt', 'Castelló de la Plana'): 0.43333333333333335,
#  ('Castelló de la Plana', 'Vinarós'): 0.6666666666666666,
#  ('Vinarós', 'Castelló de la Plana'): 0.6666666666666666,
#  ('Ciudad Real', 'Piedrabuena'): 0.2518333333333333,
#  ('Piedrabuena', 'Ciudad Real'): 0.2518333333333333,
#  ('Ciudad Real', 'Puertollano'): 0.23623333333333332,
#  ('Puertollano', 'Ciudad Real'): 0.23623333333333332,
#  ('Córdoba', 'Sevilla'): 0.8860416666666667,
#  ('Sevilla', 'Córdoba'): 0.8860416666666667,
#  ('Córdoba', 'Écija'): 0.5281555555555555,
#  ('Écija', 'Córdoba'): 0.5281555555555555,
#  ('Córdoba', 'Espiel'): 0.35725555555555555,
#  ('Espiel', 'Córdoba'): 0.35725555555555555,
#  ('Córdoba', 'Lucena'): 0.6968000000000001,
#  ('Lucena', 'Córdoba'): 0.6968000000000001,
#  ('Córdoba', 'Montoro'): 0.24635833333333332,
#  ('Montoro', 'Córdoba'): 0.24635833333333332,
#  ('Cuenca', 'Belmonte'): 0.7398444444444444,
#  ('Belmonte', 'Cuenca'): 0.7398444444444444,
#  ('Cuenca', 'Cañete'): 0.40315833333333334,
#  ('Cañete', 'Cuenca'): 0.40315833333333334,
#  ('Cuenca', 'Sacedón'): 0.6080666666666666,
#  ('Sacedón', 'Cuenca'): 0.6080666666666666,
#  ('Donostia', 'Zarauz'): 0.14600000000000002,
#  ('Zarauz', 'Donostia'): 0.14600000000000002,
#  ('Girona', 'Figueres'): 0.3543,
#  ('Figueres', 'Girona'): 0.3543,
#  ('Girona', 'Vic'): 0.48693333333333333,
#  ('Vic', 'Girona'): 0.48693333333333333,
#  ('Granada', 'Baena'): 0.6433888888888889,
#  ('Baena', 'Granada'): 0.6433888888888889,
#  ('Granada', 'Loja'): 0.438,
#  ('Loja', 'Granada'): 0.438,
#  ('Guadalajara', 'Almadrones'): 0.21934166666666668,
#  ('Almadrones', 'Guadalajara'): 0.21934166666666668,
#  ('Guadalajara', 'Venturada'): 0.40555555555555556,
#  ('Venturada', 'Guadalajara'): 0.40555555555555556,
#  ('Huelva', 'Almonte'): 0.34678888888888887,
#  ('Almonte', 'Huelva'): 0.34678888888888887,
#  ('Huelva', 'Gibraleón'): 0.15976666666666667,
#  ('Gibraleón', 'Huelva'): 0.15976666666666667,
#  ('Huelva', 'Mazagón'): 0.17546666666666666,
#  ('Mazagón', 'Huelva'): 0.17546666666666666,
#  ('Huesca', 'Barbastro'): 0.3280777777777778,
#  ('Barbastro', 'Huesca'): 0.3280777777777778,
#  ('Huesca', 'Fraga'): 0.8488444444444444,
#  ('Fraga', 'Huesca'): 0.8488444444444444,
#  ('Huesca', 'Nueno'): 0.2924555555555556,
#  ('Nueno', 'Huesca'): 0.2924555555555556,
#  ('Jaén', 'Granada'): 0.6531333333333333,
#  ('Granada', 'Jaén'): 0.6531333333333333,
#  ('León', 'Astorga'): 0.5081,
#  ('Astorga', 'León'): 0.5081,
#  ('León', 'Benavente'): 0.7708555555555555,
#  ('Benavente', 'León'): 0.7708555555555555,
#  ('León', 'Campomanes'): 0.40065555555555554,
#  ('Campomanes', 'León'): 0.40065555555555554,
#  ('Lisboa', 'Montijo'): 0.11697777777777778,
#  ('Montijo', 'Lisboa'): 0.11697777777777778,
#  ('Lisboa', 'Sintra'): 0.21151111111111112,
#  ('Sintra', 'Lisboa'): 0.21151111111111112,
#  ('Lleida', 'Les Borges Blanques'): 0.21151111111111112,
#  ('Les Borges Blanques', 'Lleida'): 0.21151111111111112,
#  ('Lleida', 'Monzón'): 0.6028444444444444,
#  ('Monzón', 'Lleida'): 0.6028444444444444,
#  ('Logroño', 'Soria'): 0.7652,
#  ('Soria', 'Logroño'): 0.7652,
#  ('Logroño', 'Gimileo'): 0.24115555555555557,
#  ('Gimileo', 'Logroño'): 0.24115555555555557,
#  ('Logroño', 'Santo Domingo de la Calzada'): 0.3818222222222222,
#  ('Santo Domingo de la Calzada', 'Logroño'): 0.3818222222222222,
#  ('Lugo', 'Baamonde'): 0.2108888888888889,
#  ('Baamonde', 'Lugo'): 0.2108888888888889,
#  ('Lugo', 'Guntín'): 0.14956666666666668,
#  ('Guntín', 'Lugo'): 0.14956666666666668,
#  ('Lugo', 'Vegadeo'): 0.7227555555555556,
#  ('Vegadeo', 'Lugo'): 0.7227555555555556,
#  ('Madrid', 'Toledo'): 0.46821666666666667,
#  ('Toledo', 'Madrid'): 0.46821666666666667,
#  ('Madrid', 'Adanero'): 0.9166666666666666,
#  ('Adanero', 'Madrid'): 0.9166666666666666,
#  ('Madrid', 'Alcalá de Henares'): 0.2079,
#  ('Alcalá de Henares', 'Madrid'): 0.2079,
#  ('Madrid', 'Arganda del Rey'): 0.21934166666666668,
#  ('Arganda del Rey', 'Madrid'): 0.21934166666666668,
#  ('Madrid', 'Maqueda'): 0.4966,
#  ('Maqueda', 'Madrid'): 0.4966,
#  ('Madrid', 'Venturada'): 0.30440833333333334,
#  ('Venturada', 'Madrid'): 0.30440833333333334,
#  ('Málaga', 'Torremolinos'): 0.08549999999999999,
#  ('Torremolinos', 'Málaga'): 0.08549999999999999,
#  ('Murcia', 'Alcantarilla'): 0.08603333333333334,
#  ('Alcantarilla', 'Murcia'): 0.08603333333333334,
#  ('Ourense', 'Ribadavia'): 0.3187111111111111,
#  ('Ribadavia', 'Ourense'): 0.3187111111111111,
#  ('Ourense', 'Xinzo de Limia'): 0.2675444444444445,
#  ('Xinzo de Limia', 'Ourense'): 0.2675444444444445,
#  ('Oviedo', 'Gijón'): 0.24115555555555557,
#  ('Gijón', 'Oviedo'): 0.24115555555555557,
#  ('Oviedo', 'Grado'): 0.18136666666666668,
#  ('Grado', 'Oviedo'): 0.18136666666666668,
#  ('Oviedo', 'Pola de Siero'): 0.19534444444444443,
#  ('Pola de Siero', 'Oviedo'): 0.19534444444444443,
#  ('Palencia', 'Osorno'): 0.4925777777777778,
#  ('Osorno', 'Palencia'): 0.4925777777777778,
#  ('Palencia', 'Quintana del Puente'): 0.32606666666666667,
#  ('Quintana del Puente', 'Palencia'): 0.32606666666666667,
#  ('Palencia', 'Villalón de Campos'): 0.37452222222222226,
#  ('Villalón de Campos', 'Palencia'): 0.37452222222222226,
#  ('Pamplona', 'Izurzun'): 0.17546666666666666,
#  ('Izurzun', 'Pamplona'): 0.17546666666666666,
#  ('Pamplona', 'Jaca'): 0.8855555555555555,
#  ('Jaca', 'Pamplona'): 0.8855555555555555,
#  ('Pontevedra', 'Ourense'): 0.6374333333333333,
#  ('Ourense', 'Pontevedra'): 0.6374333333333333,
#  ('Pontevedra', 'Vigo'): 0.31204444444444446,
#  ('Vigo', 'Pontevedra'): 0.31204444444444446,
#  ('Pontevedra', 'Vilagarcía de Arousa'): 0.19534444444444443,
#  ('Vilagarcía de Arousa', 'Pontevedra'): 0.19534444444444443,
#  ('Salamanca', 'Zamora'): 0.5692222250000001,
#  ('Zamora', 'Salamanca'): 0.5692222250000001,
#  ('Salamanca', 'Peñaranda de Bracamonte'): 0.42302222222222224,
#  ('Peñaranda de Bracamonte', 'Salamanca'): 0.42302222222222224,
#  ('Santander', 'Burgos'): 1.1288111111111112,
#  ('Burgos', 'Santander'): 1.1288111111111112,
#  ('Santander', 'Solares'): 0.11471111111111111,
#  ('Solares', 'Santander'): 0.11471111111111111,
#  ('Segovia', 'Adanero'): 0.4682,
#  ('Adanero', 'Segovia'): 0.4682,
#  ('Segovia', 'Venturada'): 0.43194444444444446,
#  ('Venturada', 'Segovia'): 0.43194444444444446,
#  ('Sevilla', 'Huelva'): 0.638375,
#  ('Huelva', 'Sevilla'): 0.638375,
#  ('Sevilla', 'Dos Hermanas'): 0.11478333333333332,
#  ('Dos Hermanas', 'Sevilla'): 0.11478333333333332,
#  ('Soria', 'Almazán'): 0.3280777777777778,
#  ('Almazán', 'Soria'): 0.3280777777777778,
#  ('Tarragona', "L'Hospitalet de l'Infant"): 0.20249166666666665,
#  ("L'Hospitalet de l'Infant", 'Tarragona'): 0.20249166666666665,
#  ('Tarragona', 'Reus'): 0.15049166666666666,
#  ('Reus', 'Tarragona'): 0.15049166666666666,
#  ('Tarragona', 'Sitges'): 0.23903333333333335,
#  ('Sitges', 'Tarragona'): 0.23903333333333335,
#  ('Teruel', 'Cañete'): 0.4933777777777778,
#  ('Cañete', 'Teruel'): 0.4933777777777778,
#  ('Teruel', 'Montalbán'): 0.6688555555555555,
#  ('Montalbán', 'Teruel'): 0.6688555555555555,
#  ('Toledo', 'Ciudad Real'): 0.7107833333333333,
#  ('Ciudad Real', 'Toledo'): 0.7107833333333333,
#  ('Toledo', 'Aranjuez'): 0.4065222222222223,
#  ('Aranjuez', 'Toledo'): 0.4065222222222223,
#  ('Valencia', 'Sagunt'): 0.1754666666666667,
#  ('Sagunt', 'Valencia'): 0.1754666666666667,
#  ('Valencia', 'Silla'): 0.09265833333333333,
#  ('Silla', 'Valencia'): 0.09265833333333333,
#  ('Valladolid', 'Palencia'): 0.40555555555555556,
#  ('Palencia', 'Valladolid'): 0.40555555555555556,
#  ('Valladolid', 'Adanero'): 0.8435555555555556,
#  ('Adanero', 'Valladolid'): 0.8435555555555556,
#  ('Valladolid', 'Peñafiel'): 0.4909777777777778,
#  ('Peñafiel', 'Valladolid'): 0.4909777777777778,
#  ('Vitoria', 'Izurzun'): 0.6658999999999999,
#  ('Izurzun', 'Vitoria'): 0.6658999999999999,
#  ('Zamora', 'Alcañices'): 0.4591222222222222,
#  ('Alcañices', 'Zamora'): 0.4591222222222222,
#  ('Zamora', 'Toro'): 0.34105555555555556,
#  ('Toro', 'Zamora'): 0.34105555555555556,
#  ('Zaragoza', 'Alfaro'): 0.8164444444444445,
#  ('Alfaro', 'Zaragoza'): 0.8164444444444445,
#  ('Zaragoza', 'Daroca'): 0.6390777777777779,
#  ('Daroca', 'Zaragoza'): 0.6390777777777779,
#  ('Zaragoza', 'Oitura'): 0.23226666666666668,
#  ('Oitura', 'Zaragoza'): 0.23226666666666668,
#  ('Zaragoza', 'Zuera'): 0.32847777777777776,
#  ('Zuera', 'Zaragoza'): 0.32847777777777776,
#  ('Abrantes', 'Castelo Branco'): 0.7478111111111111,
#  ('Castelo Branco', 'Abrantes'): 0.7478111111111111,
#  ('Adanero', 'Benavente'): 0.3276,
#  ('Benavente', 'Adanero'): 0.3276,
#  ('Adanero', 'San Rafael'): 0.3276,
#  ('San Rafael', 'Adanero'): 0.3276,
#  ('Ágreda', 'Soria'): 0.30416666666666664,
#  ('Soria', 'Ágreda'): 0.30416666666666664,
#  ('Aguilar de Campoó', 'Burgos'): 0.631,
#  ('Burgos', 'Aguilar de Campoó'): 0.631,
#  ('Aguilar de Campoó', 'Reinosa'): 0.2539222222222222,
#  ('Reinosa', 'Aguilar de Campoó'): 0.2539222222222222,
#  ('Alacant', 'Santa Pola'): 0.1026,
#  ('Santa Pola', 'Alacant'): 0.1026,
#  ('Albocàsser', "L'Alcora"): 0.2660666666666667,
#  ("L'Alcora", 'Albocàsser'): 0.2660666666666667,
#  ('Albocàsser', 'Xert'): 0.2052,
#  ('Xert', 'Albocàsser'): 0.2052,
#  ('Albufeira', 'Ourique'): 0.5949333333333333,
#  ('Ourique', 'Albufeira'): 0.5949333333333333,
#  ('Alcalá de Henares', 'Guadalajara'): 0.2612333333333333,
#  ('Guadalajara', 'Alcalá de Henares'): 0.2612333333333333,
#  ('Alcance', 'Ayora'): 0.22942222222222222,
#  ('Ayora', 'Alcance'): 0.22942222222222222,
#  ('Alcance', 'Bicorp'): 0.3264666666666667,
#  ('Bicorp', 'Alcance'): 0.3264666666666667,
#  ('Alcance', 'Casas Ibáñez'): 0.20065555555555556,
#  ('Casas Ibáñez', 'Alcance'): 0.20065555555555556,
#  ('Alcantarilla', 'Callosa del Segura'): 0.27014166666666667,
#  ('Callosa del Segura', 'Alcantarilla'): 0.27014166666666667,
#  ('Alcantarilla', 'Cieza'): 0.30049166666666666,
#  ('Cieza', 'Alcantarilla'): 0.30049166666666666,
#  ('Alcantarilla', 'Totana'): 0.20719166666666666,
#  ('Totana', 'Alcantarilla'): 0.20719166666666666,
#  ('Alcañices', 'Mogadouro'): 0.4823222222222222,
#  ('Mogadouro', 'Alcañices'): 0.4823222222222222,
#  ('Alcañiz', 'Híjar'): 0.21283333333333332,
#  ('Híjar', 'Alcañiz'): 0.21283333333333332,
#  ('Alcañiz', 'Reus'): 0.5967291666666666,
#  ('Reus', 'Alcañiz'): 0.5967291666666666,
#  ('Alcaraz', 'Albacete'): 0.7145111111111111,
#  ('Albacete', 'Alcaraz'): 0.7145111111111111,
#  ('Alcaraz', 'Úbeda'): 0.8491555555555557,
#  ('Úbeda', 'Alcaraz'): 0.8491555555555557,
#  ('Alcolea del Pinar', 'Molina de Aragón'): 0.46329166666666666,
#  ('Molina de Aragón', 'Alcolea del Pinar'): 0.46329166666666666,
#  ('Alcoy', "Sant Joan d'Alacant"): 0.23148333333333332,
#  ("Sant Joan d'Alacant", 'Alcoy'): 0.23148333333333332,
#  ('Alfaro', 'Logroño'): 0.6458444444444444,
#  ('Logroño', 'Alfaro'): 0.6458444444444444,
#  ('Alfaro', 'Ágreda'): 0.29627499999999996,
#  ('Ágreda', 'Alfaro'): 0.29627499999999996,
#  ('Alfaro', 'Tafalla'): 0.24333333333333332,
#  ('Tafalla', 'Alfaro'): 0.24333333333333332,
#  ('Algeciras', 'Tarifa'): 0.12933333333333333,
#  ('Tarifa', 'Algeciras'): 0.12933333333333333,
#  ('Almadén', 'Córdoba'): 0.8923666666666666,
#  ('Córdoba', 'Almadén'): 0.8923666666666666,
#  ('Almadrones', 'Alcolea del Pinar'): 0.24635833333333332,
#  ('Alcolea del Pinar', 'Almadrones'): 0.24635833333333332,
#  ('Almadrones', 'Sacedón'): 0.5036777777777778,
#  ('Sacedón', 'Almadrones'): 0.5036777777777778,
#  ('Almansa', 'Xàtiva'): 0.5193666666666666,
#  ('Xàtiva', 'Almansa'): 0.5193666666666666,
#  ('Almansa', 'Yecla'): 0.21151111111111112,
#  ('Yecla', 'Almansa'): 0.21151111111111112,
#  ('Almazán', 'Medinaceli'): 0.2438777777777778,
#  ('Medinaceli', 'Almazán'): 0.2438777777777778,
#  ('Almonte', 'Sevilla'): 0.5336111111111111,
#  ('Sevilla', 'Almonte'): 0.5336111111111111,
#  ('Alzira', 'Gandia'): 0.34488888888888886,
#  ('Gandia', 'Alzira'): 0.34488888888888886,
#  ('Alzira', 'Silla'): 0.21003333333333335,
#  ('Silla', 'Alzira'): 0.21003333333333335,
#  ('Alzira', 'Xàtiva'): 0.17715,
#  ('Xàtiva', 'Alzira'): 0.17715,
#  ('Amposta', 'Vinarós'): 0.22368333333333332,
#  ('Vinarós', 'Amposta'): 0.22368333333333332,
#  ('Andújar', 'Córdoba'): 0.6183666666666666,
#  ('Córdoba', 'Andújar'): 0.6183666666666666,
#  ('Andújar', 'Bailén'): 0.2938,
#  ('Bailén', 'Andújar'): 0.2938,
#  ('Ansiao', 'Castelo Branco'): 0.7285555555555555,
#  ('Castelo Branco', 'Ansiao'): 0.7285555555555555,
#  ('Ansiao', 'Coimbra'): 0.3906777777777778,
#  ('Coimbra', 'Ansiao'): 0.3906777777777778,
#  ('Ansiao', 'Leiria'): 0.46168888888888887,
#  ('Leiria', 'Ansiao'): 0.46168888888888887,
#  ('Ansiao', 'Torres Novas'): 0.5153,
#  ('Torres Novas', 'Ansiao'): 0.5153,
#  ('Antequera', 'Málaga'): 0.33086666666666664,
#  ('Málaga', 'Antequera'): 0.33086666666666664,
#  ('Antequera', 'Estepa'): 0.3906777777777778,
#  ('Estepa', 'Antequera'): 0.3906777777777778,
#  ('Antequera', 'Lucena'): 0.4328666666666666,
#  ('Lucena', 'Antequera'): 0.4328666666666666,
#  ('Aranda de Duero', 'Segovia'): 0.8055777777777777,
#  ('Segovia', 'Aranda de Duero'): 0.8055777777777777,
#  ('Aranda de Duero', 'Riaza'): 0.5091333333333333,
#  ('Riaza', 'Aranda de Duero'): 0.5091333333333333,
#  ('Aranjuez', 'Madrid'): 0.2892,
#  ('Madrid', 'Aranjuez'): 0.2892,
#  ('Aranjuez', 'Ocaña'): 0.1316,
#  ('Ocaña', 'Aranjuez'): 0.1316,
#  ('Arenas de San Pedro', 'Talavera de la Reina'): 0.3047888888888889,
#  ('Talavera de la Reina', 'Arenas de San Pedro'): 0.3047888888888889,
#  ('Arévalo', 'Adanero'): 0.162325,
#  ('Adanero', 'Arévalo'): 0.162325,
#  ('Arganda del Rey', 'Tarancón'): 0.3156333333333333,
#  ('Tarancón', 'Arganda del Rey'): 0.3156333333333333,
#  ('Armiñón', 'Vitoria'): 0.13954444444444444,
#  ('Vitoria', 'Armiñón'): 0.13954444444444444,
#  ('Armiñón', 'Miranda del Ebro'): 0.14188333333333333,
#  ('Miranda del Ebro', 'Armiñón'): 0.14188333333333333,
#  ('Astorga', 'La Bañeza'): 0.23996666666666666,
#  ('La Bañeza', 'Astorga'): 0.23996666666666666,
#  ('Astorga', 'Ponferrada'): 0.2801,
#  ('Ponferrada', 'Astorga'): 0.2801,
#  ('Aveiro', 'Figueira da Foz'): 0.5849,
#  ('Figueira da Foz', 'Aveiro'): 0.5849,
#  ('Avilés', 'Oviedo'): 0.2565,
#  ('Oviedo', 'Avilés'): 0.2565,
#  ('Ayora', 'Almansa'): 0.26407777777777774,
#  ('Almansa', 'Ayora'): 0.26407777777777774,
#  ('Ayora', 'Casa de Juan Gil'): 0.22064444444444445,
#  ('Casa de Juan Gil', 'Ayora'): 0.22064444444444445,
#  ('Ayora', 'Xàtiva'): 0.5666222222222222,
#  ('Xàtiva', 'Ayora'): 0.5666222222222222,
#  ('Baamonde', 'Arzúa'): 0.41454444444444444,
#  ('Arzúa', 'Baamonde'): 0.41454444444444444,
#  ('Baamonde', 'Becerrea'): 0.4216416666666667,
#  ('Becerrea', 'Baamonde'): 0.4216416666666667,
#  ('Baamonde', 'Betanzos'): 0.23403333333333334,
#  ('Betanzos', 'Baamonde'): 0.23403333333333334,
#  ('Baamonde', 'Vegadeo'): 0.6747333333333333,
#  ('Vegadeo', 'Baamonde'): 0.6747333333333333,
#  ('Baena', 'Córdoba'): 0.6886333333333333,
#  ('Córdoba', 'Baena'): 0.6886333333333333,
#  ('Bailén', 'Jaén'): 0.31497777777777775,
#  ('Jaén', 'Bailén'): 0.31497777777777775,
#  ('Barbastro', 'Graus'): 0.32847777777777776,
#  ('Graus', 'Barbastro'): 0.32847777777777776,
#  ('Barreiros', 'Baamonde'): 0.5281555555555555,
#  ('Baamonde', 'Barreiros'): 0.5281555555555555,
#  ('Barreiros', 'San Ciprián'): 0.2539222222222222,
#  ('San Ciprián', 'Barreiros'): 0.2539222222222222,
#  ('Basauri', 'Bilbao'): 0.06204166666666667,
#  ('Bilbao', 'Basauri'): 0.06204166666666667,
#  ('Basauri', 'Vitoria'): 0.4804111111111111,
#  ('Vitoria', 'Basauri'): 0.4804111111111111,
#  ('Basauri', 'Armiñón'): 0.41384166666666666,
#  ('Armiñón', 'Basauri'): 0.41384166666666666,
#  ('Baza', 'Granada'): 0.7234777777777778,
#  ('Granada', 'Baza'): 0.7234777777777778,
#  ('Becerrea', 'Lugo'): 0.37836666666666663,
#  ('Lugo', 'Becerrea'): 0.37836666666666663,
#  ('Becerrea', 'O Barco'): 0.4507333333333334,
#  ('O Barco', 'Becerrea'): 0.4507333333333334,
#  ('Beja', 'Grândula'): 0.6028444444444444,
#  ('Grândula', 'Beja'): 0.6028444444444444,
#  ('Beja', 'Serpa'): 0.24708888888888889,
#  ('Serpa', 'Beja'): 0.24708888888888889,
#  ('Béjar', 'Salamanca'): 0.36580833333333335,
#  ('Salamanca', 'Béjar'): 0.36580833333333335,
#  ('Belmonte', 'Daimiel'): 0.8537888888888888,
#  ('Daimiel', 'Belmonte'): 0.8537888888888888,
#  ('Benabarre', 'Lleida'): 0.6529333333333334,
#  ('Lleida', 'Benabarre'): 0.6529333333333334,
#  ('Benavente', 'Astorga'): 0.5833333333333334,
#  ('Astorga', 'Benavente'): 0.5833333333333334,
#  ('Benavente', 'Mombuey'): 0.6021888888888889,
#  ('Mombuey', 'Benavente'): 0.6021888888888889,
#  ('Benavente', 'Villalón de Campos'): 0.5375444444444444,
#  ('Villalón de Campos', 'Benavente'): 0.5375444444444444,
#  ('Benicarló', 'Vinarós'): 0.07094166666666667,
#  ('Vinarós', 'Benicarló'): 0.07094166666666667,
#  ('Benicàssim', 'Castelló de la Plana'): 0.06083333333333333,
#  ('Castelló de la Plana', 'Benicàssim'): 0.06083333333333333,
#  ('Benicàssim', 'Torreblanca'): 0.12933333333333333,
#  ('Torreblanca', 'Benicàssim'): 0.12933333333333333,
#  ('Benidorm', "Sant Joan d'Alacant"): 0.49974444444444444,
#  ("Sant Joan d'Alacant", 'Benidorm'): 0.49974444444444444,
#  ('Betanzos', 'A Coruña'): 0.19618333333333335,
#  ('A Coruña', 'Betanzos'): 0.19618333333333335,
#  ('Betanzos', 'Arzúa'): 0.36598888888888886,
#  ('Arzúa', 'Betanzos'): 0.36598888888888886,
#  ('Betanzos', 'Carballo'): 0.438,
#  ('Carballo', 'Betanzos'): 0.438,
#  ('Betanzos', 'Pontedeume'): 0.0811111111111111,
#  ('Pontedeume', 'Betanzos'): 0.0811111111111111,
#  ('Bicorp', 'Xàtiva'): 0.3601888888888889,
#  ('Xàtiva', 'Bicorp'): 0.3601888888888889,
#  ('Boltaña', 'Jaca'): 0.5896111111111111,
#  ('Jaca', 'Boltaña'): 0.5896111111111111,
#  ('Boltaña', 'Sabiñánigo'): 0.5031555555555556,
#  ('Sabiñánigo', 'Boltaña'): 0.5031555555555556,
#  ('Borriol', "L'Alcora"): 0.12354444444444444,
#  ("L'Alcora", 'Borriol'): 0.12354444444444444,
#  ('Braga', 'Porto'): 0.4285888888888889,
#  ('Porto', 'Braga'): 0.4285888888888889,
#  ('Braga', 'Ribeira de Pena'): 0.5122222222222222,
#  ('Ribeira de Pena', 'Braga'): 0.5122222222222222,
#  ('Braga', 'Valongo'): 0.4013111111111111,
#  ('Valongo', 'Braga'): 0.4013111111111111,
#  ('Bragança', 'Quintanilha'): 0.18136666666666668,
#  ('Quintanilha', 'Bragança'): 0.18136666666666668,
#  ('Burgo de Osma', 'Soria'): 0.40297499999999997,
#  ('Soria', 'Burgo de Osma'): 0.40297499999999997,
#  ('Calatayud', 'Soria'): 0.6587555555555555,
#  ('Soria', 'Calatayud'): 0.6587555555555555,
#  ('Caldas da Rainha', 'Santarem'): 0.3557777777777778,
#  ('Santarem', 'Caldas da Rainha'): 0.3557777777777778,
#  ('Campillos', 'Antequera'): 0.30864444444444444,
#  ('Antequera', 'Campillos'): 0.30864444444444444,
#  ('Campillos', 'Estepa'): 0.2438777777777778,
#  ('Estepa', 'Campillos'): 0.2438777777777778,
#  ('Campomanes', 'La Magdalena'): 0.2620777777777778,
#  ('La Magdalena', 'Campomanes'): 0.2620777777777778,
#  ('Campomanes', 'Mieres'): 0.19735555555555556,
#  ('Mieres', 'Campomanes'): 0.19735555555555556,
#  ('Cangas de Onís', 'Pola de Siero'): 0.39470000000000005,
#  ('Pola de Siero', 'Cangas de Onís'): 0.39470000000000005,
#  ('Cangas de Onís', 'Potes'): 0.34105555555555556,
#  ('Potes', 'Cangas de Onís'): 0.34105555555555556,
#  ('Cañete', 'Utiel'): 0.4103888888888889,
#  ('Utiel', 'Cañete'): 0.4103888888888889,
#  ('Carboneras', 'Almería'): 0.5803888888888888,
#  ('Almería', 'Carboneras'): 0.5803888888888888,
#  ('Carboneras', 'Adra'): 1.0367,
#  ('Adra', 'Carboneras'): 1.0367,
#  ('Carboneras', 'Vera'): 0.2833111111111111,
#  ('Vera', 'Carboneras'): 0.2833111111111111,
#  ('Carregado', 'Torres Vedras'): 0.2108888888888889,
#  ('Torres Vedras', 'Carregado'): 0.2108888888888889,
#  ('Cartagena', 'Murcia'): 0.4211555555555556,
#  ('Murcia', 'Cartagena'): 0.4211555555555556,
#  ('Cartagena', 'La Unión'): 0.10882222222222222,
#  ('La Unión', 'Cartagena'): 0.10882222222222222,
#  ('Casas Ibáñez', 'Albacete'): 0.45883333333333337,
#  ('Albacete', 'Casas Ibáñez'): 0.45883333333333337,
#  ('Casa de Juan Gil', 'Albacete'): 0.35908888888888885,
#  ('Albacete', 'Casa de Juan Gil'): 0.35908888888888885,
#  ('Cascais', 'Lisboa'): 0.20065555555555556,
#  ('Lisboa', 'Cascais'): 0.20065555555555556,
#  ('Caspe', 'Alcañiz'): 0.18987777777777776,
#  ('Alcañiz', 'Caspe'): 0.18987777777777776,
#  ('Caspe', 'Fraga'): 0.5068,
#  ('Fraga', 'Caspe'): 0.5068,
#  ('Castelldefels', 'Barcelona'): 0.15863333333333335,
#  ('Barcelona', 'Castelldefels'): 0.15863333333333335,
#  ('Castelldefels', 'Sitges'): 0.23965833333333333,
#  ('Sitges', 'Castelldefels'): 0.23965833333333333,
#  ('Castelo Branco', 'Plasencia'): 1.3203888888888888,
#  ('Plasencia', 'Castelo Branco'): 1.3203888888888888,
#  ('Castelo Branco', 'Portalegre'): 0.5849,
#  ('Portalegre', 'Castelo Branco'): 0.5849,
#  ('Castro Urdiales', 'Laredo'): 0.19735555555555556,
#  ('Laredo', 'Castro Urdiales'): 0.19735555555555556,
#  ('Caudete', 'Requena'): 0.11697777777777778,
#  ('Requena', 'Caudete'): 0.11697777777777778,
#  ('Cerceda', 'Burgos'): 0.5508444444444445,
#  ('Burgos', 'Cerceda'): 0.5508444444444445,
#  ('Cerceda', 'Santander'): 0.6458444444444444,
#  ('Santander', 'Cerceda'): 0.6458444444444444,
#  ('Cervera', 'Lleida'): 0.37346666666666667,
#  ('Lleida', 'Cervera'): 0.37346666666666667,
#  ('Cervera', 'Manresa'): 0.5517888888888889,
#  ('Manresa', 'Cervera'): 0.5517888888888889,
#  ('Chantada', 'Ourense'): 0.31204444444444446,
#  ('Ourense', 'Chantada'): 0.31204444444444446,
#  ('Chiva', 'Valencia'): 0.35725555555555555,
#  ('Valencia', 'Chiva'): 0.35725555555555555,
#  ('Chiva', 'Alzira'): 0.4815,
#  ('Alzira', 'Chiva'): 0.4815,
#  ('Chiva', 'Liria'): 0.20326666666666668,
#  ('Liria', 'Chiva'): 0.20326666666666668,
#  ('Cieza', 'Hellín'): 0.19237500000000002,
#  ('Hellín', 'Cieza'): 0.19237500000000002,
#  ('Cinctorres', 'Morella'): 0.12354444444444444,
#  ('Morella', 'Cinctorres'): 0.12354444444444444,
#  ('Cinctorres', 'Vilafranca del Cid'): 0.16303333333333334,
#  ('Vilafranca del Cid', 'Cinctorres'): 0.16303333333333334,
#  ('Cistierna', 'Cangas de Onís'): 0.45883333333333337,
#  ('Cangas de Onís', 'Cistierna'): 0.45883333333333337,
#  ('Cistierna', 'Potes'): 0.4839555555555555,
#  ('Potes', 'Cistierna'): 0.4839555555555555,
#  ('Cocentaina', 'Alcoy'): 0.06204166666666667,
#  ('Alcoy', 'Cocentaina'): 0.06204166666666667,
#  ('Coimbra', 'Aveiro'): 0.4793111111111111,
#  ('Aveiro', 'Coimbra'): 0.4793111111111111,
#  ('Coimbra', 'Castelo Branco'): 0.8664888888888889,
#  ('Castelo Branco', 'Coimbra'): 0.8664888888888889,
#  ('Coimbra', 'Guarda'): 0.8892666666666668,
#  ('Guarda', 'Coimbra'): 0.8892666666666668,
#  ('Coimbra', 'Leiria'): 0.7126666666666667,
#  ('Leiria', 'Coimbra'): 0.7126666666666667,
#  ('Collado Villalba', 'Madrid'): 0.24333333333333332,
#  ('Madrid', 'Collado Villalba'): 0.24333333333333332,
#  ('Coruche', 'Ponte do Sôr'): 0.4771111111111111,
#  ('Ponte do Sôr', 'Coruche'): 0.4771111111111111,
#  ('Coruche', 'Santarem'): 0.4135888888888889,
#  ('Santarem', 'Coruche'): 0.4135888888888889,
#  ('Covilha', 'Castelo Branco'): 0.47072222222222226,
#  ('Castelo Branco', 'Covilha'): 0.47072222222222226,
#  ('Covilha', 'Coimbra'): 0.6682666666666667,
#  ('Coimbra', 'Covilha'): 0.6682666666666667,
#  ('Cudillero', 'Avilés'): 0.1307888888888889,
#  ('Avilés', 'Cudillero'): 0.1307888888888889,
#  ('Cullera', 'Gandia'): 0.23226666666666668,
#  ('Gandia', 'Cullera'): 0.23226666666666668,
#  ('Daimiel', 'Ciudad Real'): 0.26407777777777774,
#  ('Ciudad Real', 'Daimiel'): 0.26407777777777774,
#  ('Daimiel', 'Madridejos'): 0.44277777777777777,
#  ('Madridejos', 'Daimiel'): 0.44277777777777777,
#  ('Daroca', 'Calatayud'): 0.4135888888888889,
#  ('Calatayud', 'Daroca'): 0.4135888888888889,
#  ('Dos Hermanas', 'Jerez de la Frontera'): 0.5016416666666667,
#  ('Jerez de la Frontera', 'Dos Hermanas'): 0.5016416666666667,
#  ('Durango', 'Basauri'): 0.21151111111111112,
#  ('Basauri', 'Durango'): 0.21151111111111112,
#  ('Durcal', 'Motril'): 0.2901888888888889,
#  ('Motril', 'Durcal'): 0.2901888888888889,
#  ('Durcal', 'Padul'): 0.09458888888888889,
#  ('Padul', 'Durcal'): 0.09458888888888889,
#  ('Écija', 'Lucena'): 0.6930111111111111,
#  ('Lucena', 'Écija'): 0.6930111111111111,
#  ('El Barco de Ávila', 'Ávila'): 0.7234777777777778,
#  ('Ávila', 'El Barco de Ávila'): 0.7234777777777778,
#  ('El Burgo del Ebro', 'Zaragoza'): 0.15294444166666665,
#  ('Zaragoza', 'El Burgo del Ebro'): 0.15294444166666665,
#  ('Elda', 'Novelda'): 0.14600000000000002,
#  ('Novelda', 'Elda'): 0.14600000000000002,
#  ('Elvas', 'Badajoz'): 0.2534,
#  ('Badajoz', 'Elvas'): 0.2534,
#  ('Elvas', 'Estremoz'): 0.4107111111111111,
#  ('Estremoz', 'Elvas'): 0.4107111111111111,
#  ('Elx', 'Alacant'): 0.122275,
#  ('Alacant', 'Elx'): 0.122275,
#  ('Elx', 'Callosa del Segura'): 0.2009629666666667,
#  ('Callosa del Segura', 'Elx'): 0.2009629666666667,
#  ('Elx', 'Novelda'): 0.11697777777777778,
#  ('Novelda', 'Elx'): 0.11697777777777778,
#  ('Espiel', 'Almadén'): 0.6515222222222222,
#  ('Almadén', 'Espiel'): 0.6515222222222222,
#  ('Espiel', 'Llerena'): 0.7667444444444445,
#  ('Llerena', 'Espiel'): 0.7667444444444445,
#  ('Espinho', 'Feira'): 0.12354444444444444,
#  ('Feira', 'Espinho'): 0.12354444444444444,
#  ('Estepa', 'Sevilla'): 0.9449333333333333,
#  ('Sevilla', 'Estepa'): 0.9449333333333333,
#  ('Estepona', 'Guadiaro'): 0.23648148333333333,
#  ('Guadiaro', 'Estepona'): 0.23648148333333333,
#  ('Estremoz', 'Évora'): 0.3441222222222222,
#  ('Évora', 'Estremoz'): 0.3441222222222222,
#  ('Évora', 'Beja'): 0.6164444444444445,
#  ('Beja', 'Évora'): 0.6164444444444445,
#  ('Évora', 'Grândula'): 0.6658999999999999,
#  ('Grândula', 'Évora'): 0.6658999999999999,
#  ('Évora', 'Montemor-o-Novo'): 0.2685222222222222,
#  ('Montemor-o-Novo', 'Évora'): 0.2685222222222222,
#  ('Faro', 'Albufeira'): 0.30175555555555555,
#  ('Albufeira', 'Faro'): 0.30175555555555555,
#  ('Faro', 'Tavira'): 0.34105555555555556,
#  ('Tavira', 'Faro'): 0.34105555555555556,
#  ('Feira', 'Aveiro'): 0.2539222222222222,
#  ('Aveiro', 'Feira'): 0.2539222222222222,
#  ('Figueira da Foz', 'Coimbra'): 0.40555555555555556,
#  ('Coimbra', 'Figueira da Foz'): 0.40555555555555556,
#  ('Figueres', 'La Jonquera'): 0.1386,
#  ('La Jonquera', 'Figueres'): 0.1386,
#  ('Figueres', 'Olot'): 0.5982444444444445,
#  ('Olot', 'Figueres'): 0.5982444444444445,
#  ('Figueres', 'Portbou'): 0.18136666666666668,
#  ('Portbou', 'Figueres'): 0.18136666666666668,
#  ('Fraga', 'Lleida'): 0.4068555555555555,
#  ('Lleida', 'Fraga'): 0.4068555555555555,
#  ('Fraga', 'Zaragoza'): 1.1522333333333332,
#  ('Zaragoza', 'Fraga'): 1.1522333333333332,
#  ('Fuengirola', 'Marbella'): 0.12166666666666666,
#  ('Marbella', 'Fuengirola'): 0.12166666666666666,
#  ('Fuengirola', 'Torremolinos'): 0.13765,
#  ('Torremolinos', 'Fuengirola'): 0.13765,
#  ('Gaia', 'Espinho'): 0.09733333333333333,
#  ('Espinho', 'Gaia'): 0.09733333333333333,
#  ('Gandia', 'Oliva'): 0.09458888888888889,
#  ('Oliva', 'Gandia'): 0.09458888888888889,
#  ('Gandia', 'Xàtiva'): 0.3244444444444444,
#  ('Xàtiva', 'Gandia'): 0.3244444444444444,
#  ('Gibraleón', 'Sevilla'): 0.9090222222222222,
#  ('Sevilla', 'Gibraleón'): 0.9090222222222222,
#  ('Gijón', 'Avilés'): 0.16303333333333334,
#  ('Avilés', 'Gijón'): 0.16303333333333334,
#  ('Gijón', 'Pola de Siero'): 0.23952222222222222,
#  ('Pola de Siero', 'Gijón'): 0.23952222222222222,
#  ('Gimileo', 'Armiñón'): 0.2620777777777778,
#  ('Armiñón', 'Gimileo'): 0.2620777777777778,
#  ('Grândula', 'Ourique'): 0.6384666666666667,
#  ('Ourique', 'Grândula'): 0.6384666666666667,
#  ('Grândula', 'Sines'): 0.287,
#  ('Sines', 'Grândula'): 0.287,
#  ('Graus', 'Benabarre'): 0.19601111111111108,
#  ('Benabarre', 'Graus'): 0.19601111111111108,
#  ('Grao de Sagunt', 'Valencia'): 0.19534444444444443,
#  ('Valencia', 'Grao de Sagunt'): 0.19534444444444443,
#  ('Guadiaro', 'Algeciras'): 0.18137036666666667,
#  ('Algeciras', 'Guadiaro'): 0.18137036666666667,
#  ('Guadiaro', 'La Línea de la Concepción'): 0.16303333333333334,
#  ('La Línea de la Concepción', 'Guadiaro'): 0.16303333333333334,
#  ('Guarda', 'Salamanca'): 1.3203888888888888,
#  ('Salamanca', 'Guarda'): 1.3203888888888888,
#  ('Guarda', 'Covilha'): 0.35094444444444445,
#  ('Covilha', 'Guarda'): 0.35094444444444445,
#  ('Guarda', 'Vila Real'): 0.8720888888888889,
#  ('Vila Real', 'Guarda'): 0.8720888888888889,
#  ('Guardamar del Segura', 'Torrevieja'): 0.15976666666666667,
#  ('Torrevieja', 'Guardamar del Segura'): 0.15976666666666667,
#  ('Guntín', 'Chantada'): 0.24115555555555557,
#  ('Chantada', 'Guntín'): 0.24115555555555557,
#  ('Guntín', 'Lalín'): 0.31954444444444446,
#  ('Lalín', 'Guntín'): 0.31954444444444446,
#  ('Hellín', 'Albacete'): 0.47714166666666663,
#  ('Albacete', 'Hellín'): 0.47714166666666663,
#  ('Herrera del Duque', 'Almadén'): 0.4715666666666667,
#  ('Almadén', 'Herrera del Duque'): 0.4715666666666667,
#  ('Herrera del Duque', 'Piedrabuena'): 0.8241444444444445,
#  ('Piedrabuena', 'Herrera del Duque'): 0.8241444444444445,
#  ('Híjar', 'El Burgo del Ebro'): 0.42233333333333334,
#  ('El Burgo del Ebro', 'Híjar'): 0.42233333333333334,
#  ('Híjar', 'Montalbán'): 0.46792222222222224,
#  ('Montalbán', 'Híjar'): 0.46792222222222224,
#  ('Honrubia', 'Cuenca'): 0.5213888888888889,
#  ('Cuenca', 'Honrubia'): 0.5213888888888889,
#  ('Honrubia', 'Belmonte'): 0.4107111111111111,
#  ('Belmonte', 'Honrubia'): 0.4107111111111111,
#  ('Honrubia', 'La Roda'): 0.4614111111111111,
#  ('La Roda', 'Honrubia'): 0.4614111111111111,
#  ('Ibi', 'Alcoy'): 0.09867777777777778,
#  ('Alcoy', 'Ibi'): 0.09867777777777778,
#  ('Igualada', 'Cervera'): 0.40555555555555556,
#  ('Cervera', 'Igualada'): 0.40555555555555556,
#  ('Izurzun', 'Donostia'): 0.44868888888888886,
#  ('Donostia', 'Izurzun'): 0.44868888888888886,
#  ('Jabugo', 'Valverde del Camino'): 0.29740740833333335,
#  ('Valverde del Camino', 'Jabugo'): 0.29740740833333335,
#  ('Jabugo', 'Venta El Alto'): 0.564288888888889,
#  ('Venta El Alto', 'Jabugo'): 0.564288888888889,
#  ('Jerez de la Frontera', 'Puerto Real'): 0.20323148333333335,
#  ('Puerto Real', 'Jerez de la Frontera'): 0.20323148333333335,
#  ('La Albuera', 'Badajoz'): 0.19005,
#  ('Badajoz', 'La Albuera'): 0.19005,
#  ('La Albuera', 'Jabugo'): 0.6894444416666666,
#  ('Jabugo', 'La Albuera'): 0.6894444416666666,
#  ('La Bañeza', 'Benavente'): 0.30049166666666666,
#  ('Benavente', 'La Bañeza'): 0.30049166666666666,
#  ('La Espina', 'Grado'): 0.2454888888888889,
#  ('Grado', 'La Espina'): 0.2454888888888889,
#  ('Lagos', 'Albufeira'): 0.40587777777777784,
#  ('Albufeira', 'Lagos'): 0.40587777777777784,
#  ("L'Alcora", 'Onda'): 0.16303333333333334,
#  ('Onda', "L'Alcora"): 0.16303333333333334,
#  ('Lalín', 'Ourense'): 0.4815,
#  ('Ourense', 'Lalín'): 0.4815,
#  ('Lalín', 'Chantada'): 0.23226666666666668,
#  ('Chantada', 'Lalín'): 0.23226666666666668,
#  ('Lalín', 'Vilagarcía de Arousa'): 0.4963,
#  ('Vilagarcía de Arousa', 'Lalín'): 0.4963,
#  ('La Línea de la Concepción', 'Algeciras'): 0.1181,
#  ('Algeciras', 'La Línea de la Concepción'): 0.1181,
#  ('La Magdalena', 'León'): 0.2757777777777778,
#  ('León', 'La Magdalena'): 0.2757777777777778,
#  ('La Magdalena', 'Astorga'): 0.3677777777777778,
#  ('Astorga', 'La Magdalena'): 0.3677777777777778,
#  ('Laredo', 'Cerceda'): 0.5375444444444444,
#  ('Cerceda', 'Laredo'): 0.5375444444444444,
#  ('La Roda', 'Albacete'): 0.22955833333333334,
#  ('Albacete', 'La Roda'): 0.22955833333333334,
#  ('La Roda', 'Cuenca'): 0.9738777777777778,
#  ('Cuenca', 'La Roda'): 0.9738777777777778,
#  ("La Seu d'Urgell", 'Pont de Suert'): 0.6776555555555556,
#  ('Pont de Suert', "La Seu d'Urgell"): 0.6776555555555556,
#  ('La Unión', 'Murcia'): 0.41454444444444444,
#  ('Murcia', 'La Unión'): 0.41454444444444444,
#  ('La Unión', 'Portman'): 0.07254444444444444,
#  ('Portman', 'La Unión'): 0.07254444444444444,
#  ('Leiria', 'Caldas da Rainha'): 0.4591222222222222,
#  ('Caldas da Rainha', 'Leiria'): 0.4591222222222222,
#  ('Leiria', 'Figueira da Foz'): 0.4295111111111111,
#  ('Figueira da Foz', 'Leiria'): 0.4295111111111111,
#  ('Leiria', 'Torres Novas'): 0.3645444444444444,
#  ('Torres Novas', 'Leiria'): 0.3645444444444444,
#  ('Lepe', 'Ayamonte'): 0.1026,
#  ('Ayamonte', 'Lepe'): 0.1026,
#  ('Lepe', 'Gibraleón'): 0.3244444444444444,
#  ('Gibraleón', 'Lepe'): 0.3244444444444444,
#  ('Lerma', 'Soria'): 1.0722666666666667,
#  ('Soria', 'Lerma'): 1.0722666666666667,
#  ('Lerma', 'Aranda de Duero'): 0.3080333333333333,
#  ('Aranda de Duero', 'Lerma'): 0.3080333333333333,
#  ('Les Borges Blanques', 'Tarragona'): 0.5392555555555556,
#  ('Tarragona', 'Les Borges Blanques'): 0.5392555555555556,
#  ("L'Hospitalet de l'Infant", 'Amposta'): 0.31161666666666665,
#  ('Amposta', "L'Hospitalet de l'Infant"): 0.31161666666666665,
#  ('Linares', 'Bailén'): 0.18987777777777776,
#  ('Bailén', 'Linares'): 0.18987777777777776,
#  ('Liria', 'Valencia'): 0.24333333333333332,
#  ('Valencia', 'Liria'): 0.24333333333333332,
#  ('Liria', 'Segorbe'): 0.2565,
#  ('Segorbe', 'Liria'): 0.2565,
#  ('Llanes', 'Ribadesella'): 0.2052,
#  ('Ribadesella', 'Llanes'): 0.2052,
#  ('Llerena', 'Zafra'): 0.3557777777777778,
#  ('Zafra', 'Llerena'): 0.3557777777777778,
#  ('Loja', 'Antequera'): 0.4208444444444444,
#  ('Antequera', 'Loja'): 0.4208444444444444,
#  ('Lorca', 'Puerto Lumbreras'): 0.10324166666666666,
#  ('Puerto Lumbreras', 'Lorca'): 0.10324166666666666,
#  ('Lorca', 'Totana'): 0.15304444444444443,
#  ('Totana', 'Lorca'): 0.15304444444444443,
#  ('Lorca', 'Vélez-Rubio'): 0.4407,
#  ('Vélez-Rubio', 'Lorca'): 0.4407,
#  ('Losa del Obispo', 'Cañete'): 0.4136666666666667,
#  ('Cañete', 'Losa del Obispo'): 0.4136666666666667,
#  ('Losa del Obispo', 'Liria'): 0.21934166666666668,
#  ('Liria', 'Losa del Obispo'): 0.21934166666666668,
#  ('Losa del Obispo', 'Segorbe'): 0.43679999999999997,
#  ('Segorbe', 'Losa del Obispo'): 0.43679999999999997,
#  ('Los Alcázares', 'La Unión'): 0.1539,
#  ('La Unión', 'Los Alcázares'): 0.1539,
#  ('Los Gallardos', 'Almería'): 0.4910583333333333,
#  ('Almería', 'Los Gallardos'): 0.4910583333333333,
#  ('Los Gallardos', 'Carboneras'): 0.18136666666666668,
#  ('Carboneras', 'Los Gallardos'): 0.18136666666666668,
#  ('Los Gallardos', 'Vera'): 0.11471296666666667,
#  ('Vera', 'Los Gallardos'): 0.11471296666666667,
#  ('Luarca', 'Cudillero'): 0.29200000000000004,
#  ('Cudillero', 'Luarca'): 0.29200000000000004,
#  ('Macedo de Cavaleiros', 'Bragança'): 0.2791,
#  ('Bragança', 'Macedo de Cavaleiros'): 0.2791,
#  ('Macedo de Cavaleiros', 'Murça'): 0.4430777777777778,
#  ('Murça', 'Macedo de Cavaleiros'): 0.4430777777777778,
#  ('Madridejos', 'Manzanares'): 0.5081,
#  ('Manzanares', 'Madridejos'): 0.5081,
#  ('Madridejos', 'Ocaña'): 0.5553555555555556,
#  ('Ocaña', 'Madridejos'): 0.5553555555555556,
#  ('Mansilla de la Mulas', 'León'): 0.2253666666666667,
#  ('León', 'Mansilla de la Mulas'): 0.2253666666666667,
#  ('Mansilla de la Mulas', 'Cistierna'): 0.4282777777777778,
#  ('Cistierna', 'Mansilla de la Mulas'): 0.4282777777777778,
#  ('Manzanares', 'Daimiel'): 0.2164333333333333,
#  ('Daimiel', 'Manzanares'): 0.2164333333333333,
#  ('Manzanares', 'Valdepeñas'): 0.2438777777777778,
#  ('Valdepeñas', 'Manzanares'): 0.2438777777777778,
#  ('Maqueda', 'Toledo'): 0.38285555555555556,
#  ('Toledo', 'Maqueda'): 0.38285555555555556,
#  ('Maqueda', 'Talavera de la Reina'): 0.2925083333333333,
#  ('Talavera de la Reina', 'Maqueda'): 0.2925083333333333,
#  ('Marbella', 'Estepona'): 0.23609259166666666,
#  ('Estepona', 'Marbella'): 0.23609259166666666,
#  ('Marín', 'Pontevedra'): 0.14956666666666668,
#  ('Pontevedra', 'Marín'): 0.14956666666666668,
#  ('Mataró', 'Girona'): 0.452625,
#  ('Girona', 'Mataró'): 0.452625,
#  ('Medinaceli', 'Alcolea del Pinar'): 0.22594444444444445,
#  ('Alcolea del Pinar', 'Medinaceli'): 0.22594444444444445,
#  ('Medinaceli', 'Calatayud'): 0.5749222222222222,
#  ('Calatayud', 'Medinaceli'): 0.5749222222222222,
#  ('Medina del Campo', 'Arévalo'): 0.20647500000000002,
#  ('Arévalo', 'Medina del Campo'): 0.20647500000000002,
#  ('Medina del Campo', 'Tordesillas'): 0.19805833333333334,
#  ('Tordesillas', 'Medina del Campo'): 0.19805833333333334,
#  ('Mérida', 'Cáceres'): 0.5414166666666667,
#  ('Cáceres', 'Mérida'): 0.5414166666666667,
#  ('Mérida', 'Herrera del Duque'): 1.070177777777778,
#  ('Herrera del Duque', 'Mérida'): 1.070177777777778,
#  ('Mieres', 'Oviedo'): 0.08735555555555556,
#  ('Oviedo', 'Mieres'): 0.08735555555555556,
#  ('Miranda del Ebro', 'Burgos'): 0.4218166666666667,
#  ('Burgos', 'Miranda del Ebro'): 0.4218166666666667,
#  ('Miranda del Ebro', 'Cerceda'): 0.4094333333333333,
#  ('Cerceda', 'Miranda del Ebro'): 0.4094333333333333,
#  ('Miranda del Ebro', 'Gimileo'): 0.2978,
#  ('Gimileo', 'Miranda del Ebro'): 0.2978,
#  ('Mogadouro', 'Guarda'): 0.9820777777777778,
#  ('Guarda', 'Mogadouro'): 0.9820777777777778,
#  ('Mogadouro', 'Murça'): 0.5896111111111111,
#  ('Murça', 'Mogadouro'): 0.5896111111111111,
#  ('Mombuey', 'Zamora'): 0.7398444444444444,
#  ('Zamora', 'Mombuey'): 0.7398444444444444,
#  ('Mombuey', 'Verín'): 0.8474444444444444,
#  ('Verín', 'Mombuey'): 0.8474444444444444,
#  ('Monforte de Lemos', 'Ourense'): 0.22942222222222222,
#  ('Ourense', 'Monforte de Lemos'): 0.22942222222222222,
#  ('Monóvar', 'Elda'): 0.0811111111111111,
#  ('Elda', 'Monóvar'): 0.0811111111111111,
#  ('Monreal del Campo', 'Teruel'): 0.5241555555555556,
#  ('Teruel', 'Monreal del Campo'): 0.5241555555555556,
#  ('Monreal del Campo', 'Daroca'): 0.2938,
#  ('Daroca', 'Monreal del Campo'): 0.2938,
#  ('Monreal del Campo', 'Molina de Aragón'): 0.26264166666666666,
#  ('Molina de Aragón', 'Monreal del Campo'): 0.26264166666666666,
#  ('Montalbán', 'Alcañiz'): 0.48208333333333336,
#  ('Alcañiz', 'Montalbán'): 0.48208333333333336,
#  ('Montalbán', 'Monreal del Campo'): 0.29401666666666665,
#  ('Monreal del Campo', 'Montalbán'): 0.29401666666666665,
#  ('Montemor-o-Novo', 'Coruche'): 0.34221111111111113,
#  ('Coruche', 'Montemor-o-Novo'): 0.34221111111111113,
#  ('Montijo', 'Carregado'): 0.3280777777777778,
#  ('Carregado', 'Montijo'): 0.3280777777777778,
#  ('Montijo', 'Setubal'): 0.3211888888888889,
#  ('Setubal', 'Montijo'): 0.3211888888888889,
#  ('Montoro', 'Andújar'): 0.31497777777777775,
#  ('Andújar', 'Montoro'): 0.31497777777777775,
#  ('Monzón', 'Barbastro'): 0.17546666666666666,
#  ('Barbastro', 'Monzón'): 0.17546666666666666,
#  ('Morella', 'Alcañiz'): 0.4682,
#  ('Alcañiz', 'Morella'): 0.4682,
#  ('Motril', 'Adra'): 0.30440833333333334,
#  ('Adra', 'Motril'): 0.30440833333333334,
#  ('Motril', 'Almuñecar'): 0.160025,
#  ('Almuñecar', 'Motril'): 0.160025,
#  ('Murça', 'Vila Flor'): 0.3264666666666667,
#  ('Vila Flor', 'Murça'): 0.3264666666666667,
#  ('Navalmoral de la Mata', 'Talavera de la Reina'): 0.4422083333333333,
#  ('Talavera de la Reina', 'Navalmoral de la Mata'): 0.4422083333333333,
#  ('Navia', 'La Espina'): 0.31204444444444446,
#  ('La Espina', 'Navia'): 0.31204444444444446,
#  ('Navia', 'Luarca'): 0.17844444444444443,
#  ('Luarca', 'Navia'): 0.17844444444444443,
#  ('Nueno', 'Sabiñánigo'): 0.22064444444444445,
#  ('Sabiñánigo', 'Nueno'): 0.22064444444444445,
#  ('Nules', 'Sagunt'): 0.26662963333333334,
#  ('Sagunt', 'Nules'): 0.26662963333333334,
#  ('Nules', 'Vila-real'): 0.05440833333333333,
#  ('Vila-real', 'Nules'): 0.05440833333333333,
#  ('O Barco', 'Monforte de Lemos'): 0.5472444444444444,
#  ('Monforte de Lemos', 'O Barco'): 0.5472444444444444,
#  ('Ocaña', 'Villarrobledo'): 0.7353500000000001,
#  ('Villarrobledo', 'Ocaña'): 0.7353500000000001,
#  ('Odemira', 'Lagos'): 0.5193666666666666,
#  ('Lagos', 'Odemira'): 0.5193666666666666,
#  ('Oitura', 'Tarazona'): 0.31204444444444446,
#  ('Tarazona', 'Oitura'): 0.31204444444444446,
#  ('Oliva', 'Benidorm'): 0.2924555555555556,
#  ('Benidorm', 'Oliva'): 0.2924555555555556,
#  ('Olot', 'Ripoll'): 0.09458888888888889,
#  ('Ripoll', 'Olot'): 0.09458888888888889,
#  ('Onda', 'Castelló de la Plana'): 0.16936666666666667,
#  ('Castelló de la Plana', 'Onda'): 0.16936666666666667,
#  ('Onda', 'Segorbe'): 0.35615555555555556,
#  ('Segorbe', 'Onda'): 0.35615555555555556,
#  ('Onda', 'Vila-real'): 0.1386,
#  ('Vila-real', 'Onda'): 0.1386,
#  ('Ontinyent', 'Xàtiva'): 0.1386,
#  ('Xàtiva', 'Ontinyent'): 0.1386,
#  ('Osorno', 'Aguilar de Campoó'): 0.3706333333333333,
#  ('Aguilar de Campoó', 'Osorno'): 0.3706333333333333,
#  ('Ourique', 'Beja'): 0.41548888888888885,
#  ('Beja', 'Ourique'): 0.41548888888888885,
#  ('Ourique', 'Faro'): 0.773411111111111,
#  ('Faro', 'Ourique'): 0.773411111111111,
#  ('Padul', 'Granada'): 0.1539,
#  ('Granada', 'Padul'): 0.1539,
#  ('Peniche', 'Caldas da Rainha'): 0.1791777777777778,
#  ('Caldas da Rainha', 'Peniche'): 0.1791777777777778,
#  ('Peñafiel', 'Aranda de Duero'): 0.31497777777777775,
#  ('Aranda de Duero', 'Peñafiel'): 0.31497777777777775,
#  ('Peñíscola', 'Benicarló'): 0.048666666666666664,
#  ('Benicarló', 'Peñíscola'): 0.048666666666666664,
#  ('Peñíscola', 'Torreblanca'): 0.08656481666666667,
#  ('Torreblanca', 'Peñíscola'): 0.08656481666666667,
#  ('Piedrabuena', 'Almadén'): 0.6605444444444444,
#  ('Almadén', 'Piedrabuena'): 0.6605444444444444,
#  ('Pinoso', 'Alcantarilla'): 0.5036777777777778,
#  ('Alcantarilla', 'Pinoso'): 0.5036777777777778,
#  ('Pinoso', 'Monóvar'): 0.18496666666666664,
#  ('Monóvar', 'Pinoso'): 0.18496666666666664,
#  ('Plasencia', 'Béjar'): 0.3264666666666667,
#  ('Béjar', 'Plasencia'): 0.3264666666666667,
#  ('Plasencia', 'El Barco de Ávila'): 0.39270000000000005,
#  ('El Barco de Ávila', 'Plasencia'): 0.39270000000000005,
#  ('Ponferrada', 'Becerrea'): 0.4089916666666667,
#  ('Becerrea', 'Ponferrada'): 0.4089916666666667,
#  ('Ponferrada', 'O Barco'): 0.2685222222222222,
#  ('O Barco', 'Ponferrada'): 0.2685222222222222,
#  ('Pont de Suert', 'Benabarre'): 0.30175555555555555,
#  ('Benabarre', 'Pont de Suert'): 0.30175555555555555,
#  ('Pont de Suert', 'Boltaña'): 0.4749,
#  ('Boltaña', 'Pont de Suert'): 0.4749,
#  ('Pont de Suert', 'Vielha'): 0.2833111111111111,
#  ('Vielha', 'Pont de Suert'): 0.2833111111111111,
#  ('Ponteareas', 'Ribadavia'): 0.4089916666666667,
#  ('Ribadavia', 'Ponteareas'): 0.4089916666666667,
#  ('Ponte de Lima', 'Braga'): 0.27193333333333336,
#  ('Braga', 'Ponte de Lima'): 0.27193333333333336,
#  ('Ponte de Lima', 'Viana do Castelo'): 0.19601111111111108,
#  ('Viana do Castelo', 'Ponte de Lima'): 0.19601111111111108,
#  ('Ponte de Lima', 'Xinzo de Limia'): 0.7234777777777778,
#  ('Xinzo de Limia', 'Ponte de Lima'): 0.7234777777777778,
#  ('Pontedeume', 'Ferrol'): 0.21151111111111112,
#  ('Ferrol', 'Pontedeume'): 0.21151111111111112,
#  ('Ponte do Sôr', 'Abrantes'): 0.3702777777777778,
#  ('Abrantes', 'Ponte do Sôr'): 0.3702777777777778,
#  ('Portalegre', 'Estremoz'): 0.5241555555555556,
#  ('Estremoz', 'Portalegre'): 0.5241555555555556,
#  ('Portalegre', 'Ponte do Sôr'): 0.4729555555555556,
#  ('Ponte do Sôr', 'Portalegre'): 0.4729555555555556,
#  ('Portman', 'Cartagena'): 0.1307888888888889,
#  ('Cartagena', 'Portman'): 0.1307888888888889,
#  ('Potes', 'Unquera'): 0.23395555555555556,
#  ('Unquera', 'Potes'): 0.23395555555555556,
#  ('Puertollano', 'Montoro'): 0.6041833333333333,
#  ('Montoro', 'Puertollano'): 0.6041833333333333,
#  ('Puerto Lumbreras', 'Vélez-Rubio'): 0.3706333333333333,
#  ('Vélez-Rubio', 'Puerto Lumbreras'): 0.3706333333333333,
#  ('Puerto Lumbreras', 'Vera'): 0.24241666666666667,
#  ('Vera', 'Puerto Lumbreras'): 0.24241666666666667,
#  ('Puerto Real', 'Cádiz'): 0.122275,
#  ('Cádiz', 'Puerto Real'): 0.122275,
#  ('Puerto Real', 'Chiclana de la Frontera'): 0.1791777777777778,
#  ('Chiclana de la Frontera', 'Puerto Real'): 0.1791777777777778,
#  ('Puigcerdà', "La Seu d'Urgell"): 0.2833111111111111,
#  ("La Seu d'Urgell", 'Puigcerdà'): 0.2833111111111111,
#  ('Puigcerdà', 'Llivia'): 0.10387777777777778,
#  ('Llivia', 'Puigcerdà'): 0.10387777777777778,
#  ('Quintana del Puente', 'Lerma'): 0.4220888888888889,
#  ('Lerma', 'Quintana del Puente'): 0.4220888888888889,
#  ('Quintanilha', 'Alcañices'): 0.22594444444444445,
#  ('Alcañices', 'Quintanilha'): 0.22594444444444445,
#  ('Reinosa', 'Torrelavega'): 0.3601888888888889,
#  ('Torrelavega', 'Reinosa'): 0.3601888888888889,
#  ('Requena', 'Alcance'): 0.2757777777777778,
#  ('Alcance', 'Requena'): 0.2757777777777778,
#  ('Requena', 'Casas Ibáñez'): 0.29912222222222223,
#  ('Casas Ibáñez', 'Requena'): 0.29912222222222223,
#  ('Requena', 'Chiva'): 0.3893333333333333,
#  ('Chiva', 'Requena'): 0.3893333333333333,
#  ('Requena', 'Liria'): 0.5183555555555556,
#  ('Liria', 'Requena'): 0.5183555555555556,
#  ('Requena', 'Losa del Obispo'): 0.3471666666666667,
#  ('Losa del Obispo', 'Requena'): 0.3471666666666667,
#  ('Riaza', 'San Esteban de Gormaz'): 0.27014166666666667,
#  ('San Esteban de Gormaz', 'Riaza'): 0.27014166666666667,
#  ('Riaza', 'Venturada'): 0.44103333333333333,
#  ('Venturada', 'Riaza'): 0.44103333333333333,
#  ('Ribadavia', 'Tuj'): 0.3856,
#  ('Tuj', 'Ribadavia'): 0.3856,
#  ('Ribadavia', 'Vigo'): 0.45537777777777777,
#  ('Vigo', 'Ribadavia'): 0.45537777777777777,
#  ('Ribadeo', 'Barreiros'): 0.18136666666666668,
#  ('Barreiros', 'Ribadeo'): 0.18136666666666668,
#  ('Ribadeo', 'Navia'): 0.34105555555555556,
#  ('Navia', 'Ribadeo'): 0.34105555555555556,
#  ('Ribadeo', 'Vegadeo'): 0.08735555555555556,
#  ('Vegadeo', 'Ribadeo'): 0.08735555555555556,
#  ('Ribadesella', 'Cangas de Onís'): 0.18987777777777776,
#  ('Cangas de Onís', 'Ribadesella'): 0.18987777777777776,
#  ('Ribadesella', 'Gijón'): 0.5760555555555555,
#  ('Gijón', 'Ribadesella'): 0.5760555555555555,
#  ('Ribeira de Pena', 'Murça'): 0.2685222222222222,
#  ('Murça', 'Ribeira de Pena'): 0.2685222222222222,
#  ('Ribeira de Pena', 'Vila Real'): 0.2164333333333333,
#  ('Vila Real', 'Ribeira de Pena'): 0.2164333333333333,
#  ('Rincón de la Victorio', 'Málaga'): 0.17625925833333334,
#  ('Málaga', 'Rincón de la Victorio'): 0.17625925833333334,
#  ('Rincón de la Victorio', 'Almuñecar'): 0.3408833333333333,
#  ('Almuñecar', 'Rincón de la Victorio'): 0.3408833333333333,
#  ('Ripoll', 'Puigcerdà'): 0.3601888888888889,
#  ('Puigcerdà', 'Ripoll'): 0.3601888888888889,
#  ('Ronda', 'Campillos'): 0.37346666666666667,
#  ('Campillos', 'Ronda'): 0.37346666666666667,
#  ('Ronda', 'Marbella'): 0.37871111111111116,
#  ('Marbella', 'Ronda'): 0.37871111111111116,
#  ('Ruidera', 'Manzanares'): 0.34105555555555556,
#  ('Manzanares', 'Ruidera'): 0.34105555555555556,
#  ...}

# %% [markdown]
# El algoritmo 1 (Dijkstra1) es la primera implementación del algoritmo de Dijkstra. Debe basarse en el mostrado en la diapositiva 49 del tema 1 de Teoría.

# %%
"""  # Algoritmo 1
# Esta función debe implementar el algoritmo de Dijkstra básico
#
def dijkstra1(origen,destino):

    S = set([]) # Nodos incluidos
    Q = set([]) # Nodos candidatos
    D = {} # Distancia al origen
    P = {} # Camino
    
    #carreteras = list(dicCarreteras.keys())
    #autovias = list(dicAutovias.keys())
    edges = list(dist.keys())
    
# Estas estructuras almacenan los resultados  
    nodosVisitados = set([])
    aristasVisitadas = set([])
    camino = []
    
    
    S.add(origen)
    D[origen] = 0
    ultimo = origen

    while ultimo!=destino:            
    # Extrae los nuevos candidatos
        nodosVisitados.add(ultimo)
        busca = [v for (u,v) in edges if u==ultimo]
        
        #print(busca) #(Descomentar para ver el formato de la lista de sucesores)
        for v in busca:
            Q.add(v)
            aristasVisitadas.add((ultimo,v))
            if D[ultimo] + dist[(ultimo,v)] < D[v]:
                D[v] = D[ultimo]+dist[(ultimo,v)]
                P[v] = ultimo
        index_min = D.index(np.min(np.array(D)[1:]))
        val = list(Q)[index_min-2]
        Q.remove(val)
        elegido = val
        S.add(elegido)

        # Aquí debe completarse el algoritmo de Dijkstra sobre la base 
        # de la diapositiva 49 del tema 1
        # NOTA: D es una lista y no un diccionario, ese cambio para la siguiente
        # versión
                    
    # Aquí ya ha salido del bucle
    tiempoViaje = D[ultimo]
        
    # Recupera el camino
    d = destino
    o = P[d]
    camino.append((d,o))
    while o != origen:
        d = o
        o = P[d]
        camino.append((d,o))               
        
        # Devuelve la salida.
    return (tiempoViaje, Q | S,  aristasVisitadas, camino)        """
# Out:
# '  # Algoritmo 1\n# Esta función debe implementar el algoritmo de Dijkstra básico\n#\ndef dijkstra1(origen,destino):\n\n    S = set([]) # Nodos incluidos\n    Q = set([]) # Nodos candidatos\n    D = {} # Distancia al origen\n    P = {} # Camino\n    \n    #carreteras = list(dicCarreteras.keys())\n    #autovias = list(dicAutovias.keys())\n    edges = list(dist.keys())\n    \n# Estas estructuras almacenan los resultados  \n    nodosVisitados = set([])\n    aristasVisitadas = set([])\n    camino = []\n    \n    \n    S.add(origen)\n    D[origen] = 0\n    ultimo = origen\n\n    while ultimo!=destino:            \n    # Extrae los nuevos candidatos\n        nodosVisitados.add(ultimo)\n        busca = [v for (u,v) in edges if u==ultimo]\n        \n        #print(busca) #(Descomentar para ver el formato de la lista de sucesores)\n        for v in busca:\n            Q.add(v)\n            aristasVisitadas.add((ultimo,v))\n            if D[ultimo] + dist[(ultimo,v)] < D[v]:\n                D[v] = D[ultimo]+dist[(ultimo,v)]\n                P[v] = ultimo\n        index_min = D.index(np.min(np.array(D)[1:]))\n        val = list(Q)[index_min-2]\n        Q.remove(val)\n        elegido = val\n        S.add(elegido)\n\n        # Aquí debe completarse el algoritmo de Dijkstra sobre la base \n        # de la diapositiva 49 del tema 1\n        # NOTA: D es una lista y no un diccionario, ese cambio para la siguiente\n        # versión\n                    \n    # Aquí ya ha salido del bucle\n    tiempoViaje = D[ultimo]\n        \n    # Recupera el camino\n    d = destino\n    o = P[d]\n    camino.append((d,o))\n    while o != origen:\n        d = o\n        o = P[d]\n        camino.append((d,o))               \n        \n        # Devuelve la salida.\n    return (tiempoViaje, Q | S,  aristasVisitadas, camino)        '

# %%
# Algoritmo 1
# Esta función debe implementar el algoritmo de Dijkstra básico
#
import math
def dijkstra1(origen,destino):

    S = set([]) # Nodos incluidos
    Q = set([]) # Nodos candidatos
    D = {} # Distancia al origen
    P = {} # Camino
    
    #carreteras = list(dicCarreteras.keys())
    #autovias = list(dicAutovias.keys())
    edges = list(dist.keys())  ##[('A Coruña', 'Pontedeume'), ('Pontedeume', 'A Coruña'), ('Albacete', 'Almansa'), ('Almansa', 'Albacete'),
    
# Estas estructuras almacenan los resultados  
    nodosVisitados = set([])
    aristasVisitadas = set([])
    camino = []
    for i in ciudades:
       D[i] = math.inf
    S.add(origen)
    D[origen] = 0
    ultimo = origen

    while ultimo!=destino:            
    # Extrae los nuevos candidatos
        nodosVisitados.add(ultimo)
        busca = [v for (u,v) in edges if u==ultimo]
        #AQUÍ SOLO HAY QUE HACER ESTE BUCLE. LOS SUCESORES ESTÁN EN UNA LISTA. Coste n^3
        
        print(busca) #(Descomentar para ver el formato de la lista de sucesores)
        
        ul=ultimo
        for i in busca:
            if i not in S:
                aristasVisitadas.add((ul,i))
                Q.add(i)
                if D[ul]+dist[(ul,i)]<D[i]:
                   D[i]=D[ul]+dist[(ul,i)]
                   P[i]=ul
                   ultimo=i
        min=math.inf
        for (i,j) in list(D.items()): #SÚPER INEFICIENTE
            if i in Q:
                if j<min:
                    min = j
                    min_i = i
        min_i

        ultimo = min_i
        if ultimo in Q:
            Q.remove(ultimo)
        # for i in range (0,len(Q)):
        #     if Q[i]==ultimo:
        #         Q.pop(i)
        #         break
        S.add(ultimo)
        #print(dist[(ultimo,i)])
            
        # Aquí debe completarse el algoritmo de Dijkstra sobre la base 
        # de la diapositiva 49 del tema 1
        # NOTA: D es una lista y no un diccionario, ese cambio para la siguiente
        # versión
                    
    # Aquí ya ha salido del bucle
    tiempoViaje = D[ultimo]
        
    # Recupera el camino
    d = destino
    o = P[d]
    camino.append((d,o))
    while o != origen:
        d = o
        o = P[d]
        camino.append((d,o))               
        
        # Devuelve la salida.
    return (tiempoViaje, Q | S,  aristasVisitadas, camino)

# %%
### Prueba
Origen = 'Albacete'
Destino = 'Vigo'

t=time()
Ans = dijkstra1(Origen, Destino)
t=time()-t

print('El tiempo de viaje es ', Ans[0])
print('Número de nodos: ', len(Ans[3]))
print('El tiempo de cómputo es ', t)
print('Aristas estudiadas: ', len(Ans[2]))

# Dibujar una línea negra entre los puntos candidatos
folium.Marker(
    location=[ciudades[Origen][0] , ciudades[Origen][1]],
    #icon=folium.Icon(color = 'red'),
    icon=folium.DivIcon(html=f"""
        <div><svg>
            <rect x="0", y="0" width="10" height="10", fill="red", opacity=".8" />
        </svg></div>"""),
    popup=''
).add_to(salida)
folium.Marker(
    location=[ciudades[Destino][0] , ciudades[Destino][1]],
    #icon=folium.Icon(color = 'red'),
    icon=folium.DivIcon(html=f"""
        <div><svg>
            <rect x="0", y="0" width="10" height="10", fill="red", opacity=".8" />
        </svg></div>"""),
    popup=''
).add_to(salida)
    
for arista in Ans[2]:
    #print(arista)
    linea = folium.PolyLine(locations=[ciudades[arista[0]], ciudades[arista[1]]],
                        color='black', weight=2, opacity=0.5).add_to(salida)
for arista in Ans[3]:
    linea = folium.PolyLine(locations=[ciudades[arista[0]], ciudades[arista[1]]],
                        color='red', weight=5, opacity=0.8).add_to(salida)    
salida
# Out:
# ['Almansa', 'Ruidera', 'Tarancón', 'Alcaraz', 'Casas Ibáñez', 'Casa de Juan Gil', 'Hellín', 'La Roda']
# ['Honrubia', 'Albacete', 'Cuenca', 'Villarrobledo']
# ['Ayora', 'Albacete']
# ['Alcance', 'Albacete', 'Requena']
# ['Albacete', 'Xàtiva', 'Yecla', 'Ayora']
# ['Cieza', 'Albacete']
# ['Ocaña', 'Belmonte', 'Honrubia', 'La Roda', 'Manzanares']
# ['Alcance', 'Almansa', 'Casa de Juan Gil', 'Xàtiva']
# ['Ayora', 'Bicorp', 'Casas Ibáñez', 'Requena']
# ['Alcantarilla', 'Hellín', 'Yecla']
# ['Almansa', 'Cieza', 'Elda', 'Pinoso', 'Villena']
# ['Cuenca', 'Belmonte', 'La Roda', 'Utiel', 'Villarrobledo']
# ['Albacete', 'Úbeda']
# ['Albacete', 'Arganda del Rey', 'Cuenca', 'Madrid', 'Belmonte', 'Ocaña']
# ['Caudete', 'Alcance', 'Casas Ibáñez', 'Chiva', 'Liria', 'Losa del Obispo']
# ['Cuenca', 'Daimiel', 'Honrubia', 'Tarancón', 'Villarrobledo']
# ['Albacete', 'Manzanares']
# ['Requena', 'Utiel']
# ['Alcantarilla', 'Monóvar', 'Yecla']
# ['Elda', 'Ibi', 'Ontinyent', 'Yecla']
# ['Cañete', 'Caudete', 'Honrubia']
# ['Murcia', 'Callosa del Segura', 'Cieza', 'Totana', 'Pinoso']
# ['Alcance', 'Xàtiva']
# ['Almansa', 'Alzira', 'Ayora', 'Bicorp', 'Gandia', 'Ontinyent', 'Cocentaina', 'Silla']
# ['Novelda', 'Monóvar', 'Villena', 'Yecla']
# ['Madrid', 'Tarancón']
# ['Alcantarilla', 'Cartagena', 'La Unión']
# ['Cañete', 'Liria', 'Segorbe', 'Requena']
# ['Elda', 'Pinoso']
# ['Aranjuez', 'Madridejos', 'Villarrobledo', 'Tarancón']
# ['Xàtiva', 'Villena']
# ['Madridejos', 'Daimiel', 'Valdepeñas', 'Ruidera', 'Villarrobledo']
# ['Valencia', 'Alzira', 'Liria', 'Requena']
# ['Gandia', 'Silla', 'Xàtiva', 'Chiva']
# ['Alcantarilla', 'Lorca']
# ['Elda', 'Elx']
# ['Alcoy', 'Xàtiva']
# ['Alcoy', 'Villena']
# ['Belmonte', 'Cañete', 'Sacedón', 'Honrubia', 'La Roda', 'Tarancón']
# ['Alcantarilla', 'Elx']
# ["Sant Joan d'Alacant", 'Cocentaina', 'Ibi']
# ['Toledo', 'Madrid', 'Ocaña']
# ['Toledo', 'Adanero', 'Alcalá de Henares', 'Arganda del Rey', 'Maqueda', 'Venturada', 'Aranjuez', 'Collado Villalba', 'Tarancón']
# ['Chiva', 'Valencia', 'Segorbe', 'Losa del Obispo', 'Requena']
# ['Alacant', 'Callosa del Segura', 'Novelda']
# ['Alzira', 'Cullera', 'Oliva', 'Xàtiva']
# ['Puerto Lumbreras', 'Totana', 'Vélez-Rubio']
# ['Belmonte', 'Ciudad Real', 'Madridejos', 'Manzanares']
# ['Cuenca', 'Teruel', 'Utiel', 'Losa del Obispo']
# ['Valencia', 'Alzira', 'Sueca', 'Xàtiva']
# ['Manzanares', 'Bailén', 'Linares']
# ['Gandia', 'Benidorm']
# ['Santa Pola', 'Elx', "Sant Joan d'Alacant"]
# ['Lorca', 'Vélez-Rubio', 'Vera']
# ['Cartagena', 'Murcia', 'Portman', 'Los Alcázares']
# ['Sagunt', 'Silla', 'Chiva', 'Grao de Sagunt', 'Liria']
# ['Murcia', 'La Unión', 'Portman']
# ['Madrid', 'Guadalajara', 'Venturada']
# ['Alcoy', 'Benidorm', 'Alacant']
# ['Madrid', 'San Rafael']
# ['Alacant', 'Guardamar del Segura']
# ['Liria', 'Losa del Obispo', 'Onda', 'Sagunt', 'Teruel']
# ['La Unión', 'Cartagena']
# ['Gandia', 'Sueca']
# ['Alcaraz', 'Linares']
# ['Guadalajara', 'Madrid', 'Segovia', 'Riaza', 'Alcalá de Henares', 'Aranda de Duero']
# ['Silla', 'Cullera']
# ['Piedrabuena', 'Puertollano', 'Toledo', 'Daimiel']
# ['La Unión', 'Torrevieja']
# ['Daimiel', 'Manzanares', 'Ocaña']
# ['Castelló de la Plana', 'Valencia', 'Nules', 'Grao de Sagunt', 'Segorbe']
# ['Ávila', 'Adanero', 'Segovia', 'Collado Villalba']
# ['Madrid', 'Ciudad Real', 'Aranjuez', 'Maqueda']
# ['Valencia', 'Sagunt']
# ['Carboneras', 'Los Gallardos', 'Puerto Lumbreras']
# ['Torrevieja', 'Santa Pola']
# ["Sant Joan d'Alacant", 'Oliva']
# ['Almadrones', 'Venturada', 'Alcalá de Henares', 'Sacedón']
# ['Ávila', 'Madrid', 'Toledo', 'Talavera de la Reina']
# ['Lorca', 'Puerto Lumbreras', 'Baza']
# ['Almería', 'Carboneras', 'Vera']
# ['Cuenca', 'Almadrones', 'Guadalajara']
# ['Guardamar del Segura', 'Los Alcázares']
# ['Bailén', 'Úbeda', 'Valdepeñas']
# ['Ciudad Real', 'Montoro']
# ['Cañete', 'Montalbán', 'Monreal del Campo', 'Segorbe']
# ['Ciudad Real', 'Herrera del Duque', 'Almadén']
# ["L'Alcora", 'Castelló de la Plana', 'Segorbe', 'Vila-real']
# ['Sagunt', 'Vila-real']
# ['Almería', 'Adra', 'Vera', 'Los Gallardos']
# ['Guadalajara', 'Alcolea del Pinar', 'Sacedón']
# ['Nules', 'Onda', 'Castelló de la Plana']
# ['Ávila', 'Madrid', 'Segovia', 'Valladolid', 'Benavente', 'San Rafael', 'Arévalo']
# ['Adanero', 'Venturada', 'Aranda de Duero', 'San Rafael']
# ['Aranda de Duero', 'San Esteban de Gormaz', 'Venturada']
# ['Andújar', 'Jaén', 'Linares', 'Valdepeñas']
# ['Borriol', 'Sagunt', 'Vinarós', 'Benicàssim', 'Onda', 'Vila-real']
# ['Albocàsser', 'Borriol', 'Onda']
# ['Arenas de San Pedro', 'Maqueda', 'Navalmoral de la Mata', 'Herrera del Duque']
# ['Castelló de la Plana', 'Torreblanca']
# ['Castelló de la Plana', "L'Alcora"]
# ['Adanero', 'Arenas de San Pedro', 'Arévalo', 'Maqueda', 'Peñaranda de Bracamonte', 'San Rafael', 'El Barco de Ávila']
# ['Ávila', 'Adanero', 'Medina del Campo']
# ['Molina de Aragón', 'Almadrones', 'Medinaceli']
# ['Benicàssim', 'Peñíscola', 'Albocàsser']
# ['Adra', 'Carboneras', 'Los Gallardos']
# ['Riaza', 'Aranda de Duero', 'Burgo de Osma']
# ['Segovia', 'Riaza', 'Lerma', 'Peñafiel', 'San Esteban de Gormaz', 'Venturada']
# ["L'Alcora", 'Xert', 'Torreblanca', 'Vilafranca del Cid']
# ['León', 'Adanero', 'Astorga', 'Mombuey', 'Villalón de Campos', 'La Bañeza', 'Tordesillas']
# ['Benicarló', 'Torreblanca']
# ['Córdoba', 'Bailén', 'Montoro']
# ['Granada', 'Bailén']
# ['Arévalo', 'Tordesillas']
# ['Ávila', 'Talavera de la Reina']
# ['Vinarós', 'Peñíscola']
# ['Teruel', 'Daroca', 'Molina de Aragón', 'Montalbán']
# ['Soria', 'San Esteban de Gormaz']
# ['Almazán', 'Alcolea del Pinar', 'Calatayud']
# ['Castelló de la Plana', 'Amposta', 'Benicarló', 'Xert']
# ['Córdoba', 'Andújar', 'Puertollano']
# ['Talavera de la Reina', 'Trujillo']
# ['Granada', 'Vélez-Rubio']
# ['Albocàsser', 'Morella', 'Vinarós']
# ['Córdoba', 'Espiel', 'Herrera del Duque', 'Piedrabuena']
# ['Teruel', 'Híjar', 'Alcañiz', 'Monreal del Campo']
# ['Medina del Campo', 'Valladolid', 'Benavente', 'Toro']
# ['Cinctorres', 'Albocàsser']
# ['Burgos', 'Soria', 'Aranda de Duero', 'Quintana del Puente']
# ['Astorga', 'Benavente']
# ['Valladolid', 'Aranda de Duero']
# ['Almería', 'Carboneras', 'Motril']
# ['Alcolea del Pinar', 'Monreal del Campo']
# ['Vinarós', "L'Hospitalet de l'Infant"]
# ['Ávila', 'Salamanca']
# ['Soria', 'Medinaceli']
# ['Zaragoza', 'Calatayud', 'Monreal del Campo']
# ['Almadén', 'Piedrabuena', 'Mérida', 'Talavera de la Reina']
# ['Sevilla', 'Écija', 'Espiel', 'Lucena', 'Montoro', 'Almadén', 'Andújar', 'Baena']
# ['Morella', 'Vilafranca del Cid']
# ['Logroño', 'Almazán', 'Ágreda', 'Burgo de Osma', 'Calatayud', 'Lerma']
# ['Cinctorres', 'Alcañiz', 'Xert']
# ['Palencia', 'Adanero', 'Peñafiel', 'Tordesillas', 'Villalón de Campos']
# ['Cáceres', 'Mérida', 'Navalmoral de la Mata']
# ['Ávila', 'Plasencia']
# ['Palencia', 'Benavente', 'Valladolid', 'Mansilla de la Mulas']
# ['León', 'La Bañeza', 'Ponferrada', 'Benavente', 'La Magdalena']
# ['Zamora', 'Tordesillas']
# ['Palencia', 'Lerma', 'Quintana del Puente', 'Santander', 'Aguilar de Campoó', 'Cerceda', 'Miranda del Ebro', 'Santo Domingo de la Calzada']
# ['Benavente', 'Zamora', 'Verín']
# ['Durcal', 'Adra', 'Almuñecar']
# ['Tarragona', 'Amposta']
# ['Soria', 'Daroca', 'Medinaceli']
# ['Baena', 'Loja', 'Jaén', 'Baza', 'Padul']
# ['Alcañiz', 'El Burgo del Ebro', 'Montalbán']
# ['Híjar', 'Reus', 'Caspe', 'Montalbán', 'Morella']
# ['Burgos', 'Palencia', 'Lerma']
# ['Córdoba', 'Almadén', 'Llerena']
# ['Astorga', 'Benavente', 'Campomanes', 'La Magdalena', 'Mansilla de la Mulas']
# ['Zamora', 'Peñaranda de Bracamonte', 'Béjar', 'Guarda']
# ['Motril', 'Rincón de la Victorio']
# ['Soria', 'Alfaro', 'Tarazona']
# ['Astorga', 'Becerrea', 'O Barco']
# ['Durcal', 'Granada']
# ["L'Hospitalet de l'Infant", 'Reus', 'Sitges', 'Les Borges Blanques']
# ['Salamanca', 'Alcañices', 'Toro', 'Mombuey']
# ['Alcañiz', 'Fraga']
# ['Motril', 'Padul']
# ['Campomanes', 'León', 'Astorga']
# ['Burgos', 'Osorno', 'Quintana del Puente', 'Villalón de Campos', 'Valladolid']
# ['Córdoba', 'Lucena']
# ['Cáceres', 'Castelo Branco', 'Béjar', 'El Barco de Ávila']
# ['Oitura', 'Ágreda', 'Alfaro']
# ['Armiñón', 'Burgos', 'Cerceda', 'Gimileo']
# ['León', 'Cistierna', 'Villalón de Campos']
# ['Alfaro', 'Daroca', 'Oitura', 'Zuera', 'El Burgo del Ebro', 'Fraga']
# ['Tarragona', 'Alcañiz']
# ['Plasencia', 'Trujillo', 'Valencia de Alcántara', 'Mérida']
# ['Granada', 'Córdoba']
# ['Zaragoza', 'Logroño', 'Ágreda', 'Tafalla', 'Tarazona']
# ['Córdoba', 'Antequera', 'Écija']
# ['Becerrea', 'Monforte de Lemos', 'Ponferrada']
# ['Tarragona', 'Castelldefels', 'Vilafranca del Penedés']
# ['Zaragoza', 'Híjar']
# ['Burgos', 'Santander', 'Laredo', 'Miranda del Ebro']
# ['Málaga', 'Almuñecar']
# ['Badajoz', 'Cáceres', 'Herrera del Duque', 'Trujillo']
# ['Vitoria', 'Miranda del Ebro', 'Basauri', 'Gimileo']
# ['Granada', 'Antequera']
# ['Salamanca', 'Plasencia']
# ['Logroño', 'Burgos']
# ['León', 'La Magdalena', 'Mieres']
# ['Burgos', 'Reinosa', 'Osorno']
# ['Baamonde', 'Lugo', 'O Barco', 'Ponferrada']
# ['Zaragoza', 'Tarazona']
# ['Soria', 'Gimileo', 'Santo Domingo de la Calzada', 'Alfaro']
# ['Izurzun', 'Armiñón', 'Basauri']
# ['Córdoba', 'Huelva', 'Dos Hermanas', 'Almonte', 'Estepa', 'Gibraleón']
# ['Logroño', 'Armiñón', 'Miranda del Ebro']
# ['Torremolinos', 'Antequera', 'Rincón de la Victorio']
# ['Alfaro', 'Pamplona']
# ['Zaragoza', 'Huesca']
# ['Barcelona', 'Sitges']
# ['Zamora', 'Mogadouro', 'Quintanilha']
# ['Campomanes', 'Oviedo']
# ['Málaga', 'Fuengirola']
# ['Sevilla', 'Jerez de la Frontera']
# ['Huesca', 'Caspe', 'Lleida', 'Zaragoza']
# ['Barcelona', 'Sitges']
# ['Lleida', 'Tarragona']
# ['Palencia', 'Aguilar de Campoó']
# ['Cangas de Onís', 'Potes', 'Mansilla de la Mulas']
# ['Aguilar de Campoó', 'Torrelavega']
# ['Mombuey', 'Ribeira de Pena', 'Xinzo de Limia']
# ['Gijón', 'Grado', 'Pola de Siero', 'Avilés', 'Mieres']
# ['Igualada', 'Manresa', 'Mataró', 'Vic', 'Vilafranca del Penedés', 'Castelldefels']
# ['Espiel', 'Zafra']
# ['Marbella', 'Torremolinos']
# ['Málaga', 'Estepa', 'Lucena', 'Campillos', 'Loja']
# ['Mérida', 'Elvas', 'La Albuera']
# ['Bilbao', 'Vitoria', 'Armiñón', 'Durango']
# ['Izurzun', 'Jaca', 'Tafalla']
# ['Bragança', 'Alcañices']
# ['Castro Urdiales', 'Basauri']
# ['Baamonde', 'Guntín', 'Vegadeo', 'Becerrea']
# ['Les Borges Blanques', 'Monzón', 'Benabarre', 'Cervera', 'Fraga']
# ['Ourense', 'O Barco']
# ['Oviedo', 'La Espina']
# ['Fuengirola', 'Estepona', 'Ronda']
# ['Oviedo', 'Cangas de Onís', 'Gijón']
# ['Lugo', 'Arzúa', 'Becerrea', 'Betanzos', 'Vegadeo', 'Barreiros']
# ['Castro Urdiales', 'Cerceda', 'Solares']
# ['Barcelona', 'Girona']
# ['Burgos', 'Solares', 'Cerceda', 'Torrelavega']
# ['Oviedo', 'Avilés', 'Pola de Siero', 'Ribadesella']
# ['Oviedo', 'Cudillero', 'Gijón']
# ['Pamplona', 'Vitoria', 'Donostia']
# ['Ourense', 'Ponte de Lima', 'Verín']
# ['Badajoz', 'Jabugo', 'Zafra']
# ['Cáceres']
# ['Basauri', 'Zarauz']
# ['Quintanilha', 'Macedo de Cavaleiros']
# ['Lugo', 'Chantada', 'Lalín']
# ['Badajoz', 'Estremoz']
# ['Santander', 'Laredo']
# ['Bilbao', 'Laredo']
# ['Reinosa', 'Santander', 'Unquera']
# ['Huelva', 'Sevilla']
# ['Barbastro', 'Fraga', 'Nueno', 'Zuera']
# ['Antequera', 'Estepa', 'Ronda']
# ['Alcañices', 'Guarda', 'Murça', 'Vila Flor']
# ['Avilés', 'Luarca']
# ['Ribadavia', 'Xinzo de Limia', 'Pontevedra', 'Chantada', 'Lalín', 'Monforte de Lemos']
# ['Llerena', 'La Albuera']
# ['Guadiaro', 'Marbella']
# ['Grado', 'Navia']
# ['Pola de Siero', 'Potes', 'Cistierna', 'Ribadesella']
# ['Baamonde', 'A Coruña', 'Arzúa', 'Carballo', 'Pontedeume', 'Santiago de Compostela']
# ['Dos Hermanas', 'Puerto Real']
# ['Cangas de Onís', 'Cistierna', 'Unquera']
# ['Antequera', 'Campillos', 'Sevilla']
# ['Almonte', 'Gibraleón', 'Mazagón', 'Sevilla', 'Valverde del Camino']
# ['Braga', 'Murça', 'Vila Real', 'Verín']
# ['Barcelona', 'Cervera']
# ['A Coruña', 'Betanzos', 'Ferrol']
# ['Lleida', 'Manresa', 'Igualada']
# ['Ourense', 'Guntín', 'Lalín']
# ['Campillos', 'Marbella']
# ['Bragança', 'Murça']
# ['Baamonde', 'Betanzos']
# ['Llanes', 'Cangas de Onís', 'Gijón']
# ['Huelva', 'Sevilla', 'Lepe']
# ['Guntín', 'Ourense', 'Chantada', 'Vilagarcía de Arousa', 'Santiago de Compostela']
# ['Pontedeume', 'Betanzos']
# ['Huelva']
# ['Coimbra', 'Salamanca', 'Covilha', 'Vila Real', 'Mogadouro', 'Vila Nova de Foz Côa', 'Viseu']
# ['Jerez de la Frontera', 'Cádiz', 'Chiclana de la Frontera']
# ['Barcelona', 'Cervera', 'Vic']
# ['Huesca', 'Sabiñánigo']
# ['Estepona', 'Algeciras', 'La Línea de la Concepción']
# ['Donostia', 'Durango']
# ['Figueres', 'Vic', 'Mataró']
# ['Barcelona', 'Girona', 'Manresa']
# ['Murça', 'Mogadouro', 'Vila Nova de Foz Côa']
# ['Cudillero', 'Navia']
# ['Huesca', 'Graus', 'Monzón']
# ['Potes', 'Llanes', 'Torrelavega']
# ['Guarda', 'Ribeira de Pena', 'Valongo', 'Braga', 'Murça', 'Viseu']
# ['Zarauz', 'Izurzun']
# ['Pontedeume']
# ['Baamonde', 'San Ciprián', 'Ribadeo']
# ['Ourense', 'Ponteareas', 'Tuj', 'Vigo']
# ['La Espina', 'Luarca', 'Ribadeo', 'Vegadeo']
# ['Jabugo', 'Huelva']
# ['Macedo de Cavaleiros', 'Mogadouro', 'Vila Flor', 'Ribeira de Pena', 'Vila Real']
# ['Elvas', 'Évora', 'Portalegre']
# ['Puerto Real', 'San Fernando']
# ['Lleida', 'Barbastro']
# ['Abrantes', 'Ansiao', 'Plasencia', 'Portalegre', 'Coimbra', 'Covilha']
# ['Lleida', 'Graus', 'Pont de Suert']
# ['Guadiaro', 'Algeciras']
# ['Puerto Real', 'San Fernando', 'Tarifa']
# ['Ribadesella', 'Unquera']
# ['Tarifa', 'Guadiaro', 'La Línea de la Concepción']
# ['Cádiz', 'Chiclana de la Frontera']
# ['Betanzos']
# ['Lugo', 'Baamonde', 'Ribadeo', 'Navia']
# ['Boltaña', 'Nueno', 'Jaca']
# ['Barreiros', 'Navia', 'Vegadeo']
# ['Vila Flor', 'Guarda']
# ['Ayamonte', 'Gibraleón']
# ['Valverde del Camino', 'Venta El Alto', 'La Albuera', 'Serpa']
# ['Algeciras', 'Chiclana de la Frontera']
# ['Pamplona', 'Boltaña', 'Sabiñánigo']
# ['Barreiros']
# ['Porto', 'Ribeira de Pena', 'Valongo', 'Ponte de Lima', 'Vila Real']
# ['Betanzos', 'Lalín', 'Vilagarcía de Arousa']
# ['Castelo Branco', 'Coimbra', 'Guarda']
# ['Braga', 'Viana do Castelo', 'Xinzo de Limia', 'Tuj']
# ['Barbastro', 'Benabarre']
# ['Girona', 'La Jonquera', 'Olot', 'Portbou']
# ['Lepe', 'Vilareal de Santo Antonio']
# ['Ourense', 'Vigo', 'Vilagarcía de Arousa', 'Marín']
# ['Estremoz', 'Beja', 'Grândula', 'Montemor-o-Novo']
# ['Ribadavia', 'Ponte de Lima', 'Vigo']
# ["La Seu d'Urgell", 'Benabarre', 'Boltaña', 'Vielha']
# ['Pontevedra', 'Lalín', 'Santiago de Compostela']
# ['Ribadavia']
# ['Aveiro', 'Coimbra', 'Guarda', 'Vila Real']
# ['Tavira', 'Ayamonte', 'Beja']
# ['Figueres']
# El tiempo de viaje es  4.958527777777777
# Número de nodos:  15
# El tiempo de cómputo es  0.07565450668334961
# Aristas estudiadas:  550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6feef8338a812e4ef0b8aa8a4cc181d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6feef8338a812e4ef0b8aa8a4cc181d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6feef8338a812e4ef0b8aa8a4cc181d2 = L.map(
#                 &quot;map_6feef8338a812e4ef0b8aa8a4cc181d2&quot;,
#                 {
#                     center: [40.61331950370985, -3.5532346331037137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a10a43bd6f18f9a7136fcf239ba30e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a10a43bd6f18f9a7136fcf239ba30e5.addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var marker_8d2a30ea73b0fb2a9cc36bde981b6481 = L.marker(
#                 [43.37012643, -8.39114853],
#                 {
# }
#             ).addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var div_icon_cdec393e9078f11341b004bf5c11925b = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_8d2a30ea73b0fb2a9cc36bde981b6481.setIcon(div_icon_cdec393e9078f11341b004bf5c11925b);
#
#
#         var popup_6829f4dfe66c05f3f1a1299557b2de51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f28dc8d9b2d1e4b08ca9ac57d0fef0 = $(`&lt;div id=&quot;html_01f28dc8d9b2d1e4b08ca9ac57d0fef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_6829f4dfe66c05f3f1a1299557b2de51.setContent(html_01f28dc8d9b2d1e4b08ca9ac57d0fef0);
#
#
#
#         marker_8d2a30ea73b0fb2a9cc36bde981b6481.bindPopup(popup_6829f4dfe66c05f3f1a1299557b2de51)
#         ;
#
#
#
#
#                 marker_8d2a30ea73b0fb2a9cc36bde981b6481.setIcon(div_icon_cdec393e9078f11341b004bf5c11925b);
#
#
#             var marker_d5dd46170b5a7e3a0b6ea0e039058b40 = L.marker(
#                 [38.99588053, -1.85574745],
#                 {
# }
#             ).addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var div_icon_7c320ad1a243d10151cea00ea045642e = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_d5dd46170b5a7e3a0b6ea0e039058b40.setIcon(div_icon_7c320ad1a243d10151cea00ea045642e);
#
#
#         var popup_0ed30024c2d89a964f9792ba2633a602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_683bd27ccb549967b2f652df52793d19 = $(`&lt;div id=&quot;html_683bd27ccb549967b2f652df52793d19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_0ed30024c2d89a964f9792ba2633a602.setContent(html_683bd27ccb549967b2f652df52793d19);
#
#
#
#         marker_d5dd46170b5a7e3a0b6ea0e039058b40.bindPopup(popup_0ed30024c2d89a964f9792ba2633a602)
#         ;
#
#
#
#
#                 marker_d5dd46170b5a7e3a0b6ea0e039058b40.setIcon(div_icon_7c320ad1a243d10151cea00ea045642e);
#
#
#             var marker_4909c7bfdd60322528ac8c62afa7212f = L.marker(
#                 [38.34548705, -0.4831832],
#                 {
# }
#             ).addTo(map_6feef8338a812e4ef0b8aa8a4cc181d2);
#
#
#             var div_icon_d02f64a39eb65b0a87f8fb3349bda692 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4909c7bfdd60322528ac8c62afa7212f.setIcon(div_icon_d02f64a39eb65b0a87f8fb3349bda692);
#
#
#         var popup_0dab4640d17dfce9d290c711cf91f38e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3698758564904b3c98e49ee7474b3cf2 = $(`&lt;div id=&quot;html_3698758564904b3c98e49ee7474b3cf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_0dab4640d17dfce9d290c711cf91f38e.setContent(html_3698758564904b3c98e49ee7474b3cf2);
#
#
#
#         ma

# %% [markdown]
# La implementación del algoritmos de Dijkstra basada en la vista en clase tiene el problema de que la búsqueda del mínimo elemento para tomar el siguiente a incorporar en la solución nos toma un tiempo lineal, pues hay que recorrer todos los nodos de Q para saber cual tiene menor distancia. Esto se puede mejorar si la lista D de distancias al origen ya calculadas, como una cola con prioridad.
#
# Para ello, en primer lugar construimos la clase dicPrioridad basada en lo visto en clase.

# %%
#
# Esta clase implementa un diccionario de prioridad
#
class dicPrioridad:
    
    # Constructor. Opcionalmente toma una lista de pares
    # (elemento,valor)
    def __init__(self,objetos=[]):
        self.diccionario = {}
        self.vector = [ ]
        self.tamano = -1 # Realmente es el índice del último elemento.
        # Se insertan de uno en uno los objetos.
        for (elemento,valor) in objetos:
            item = (elemento, valor)
            self.inserta(item)
 
      # Inserta un elemento
    def inserta(self, item):
        # Lo añade al final
        self.vector.append(item)
        self.tamano += 1
        
        #
        #  COMPLETAR
        #
        if len(self.diccionario) == 0:
            self.diccionario[item[0]] = self.tamano # item ('C',1) --> {'C':1,..}
        else:
            aux = []
            while len(self.diccionario)!=0:
                copia = list(self.diccionario.items()).pop()
                index = copia[1]
                if self.vector[index][1] >= item[1]:
                    break
                aux.append(copia)
                nombre = copia[0]
                del(self.diccionario[nombre])
            self.diccionario[item[0]] = self.tamano
            while len(aux) != 0:
                copia = aux.pop()
                nombre = copia[0]
                val = copia[1]
                self.diccionario[nombre] = val
            

    
    # Extrae el elemento mínimo del diccionario de prioridad
    def extrae_min(self):
        # Si el tamaño es -1, no devuelve nada
        if self.tamano == -1:
            return None
        #
        #  COMPLETAR
        #
        #return self.diccionario[self.tamano]
        #for i in self.diccionario.keys():
        #    return i
        #return self.vector.pop()
        key = list(self.diccionario).pop() # e.g. 'A'
        index = self.diccionario[key]
        return self.vector[index]

    # Actualiza el valor de un elemento 
    def actualiza(self, item):
            # Posición del elemento que se va a modificar
            indice = self.diccionario[item[0]]
            # Se actualiza el elemento        
            self.vector[indice] = item

            #
            #  COMPLETAR
            #

            tupla = (item[0],indice)
            del(self.diccionario[tupla[0]])
            aux =[]
            while True:
                if len(self.diccionario)==0:
                    break
                copia = list(self.diccionario.items()).pop()
                if self.vector[copia[1]][1] >= self.vector[tupla[1]][1]:
                    break
                aux.append(copia)
                del(self.diccionario[copia[0]])
            self.diccionario[tupla[0]] = tupla[1]
            while len(aux) != 0:
                tupla = aux.pop()
                self.diccionario[tupla[0]] = tupla[1]
    # Borra un elemento de la cola
    # No haremos uso de esta función
    def borra(self, elemento):
        # Si el elemento no está en el diccionario, vuelve
        if elemento not in self.diccionario:
            return
        # Índice del elemento
        indice = self.diccionario[elemento]
        # Lo intercambiamos con el último
        self.cambia_elementos(indice, self.tamano)
  
        # Borra el diccionario y del vector
        del(self.diccionario[elemento])
        del(self.vector[self.tamano])
        # Decrece el tamaño
        self.tamano -= 1        
        # Se arregla el heap
        # Se saca la posición del padre
        padre = self.nodopadre(indice)
        # Si el nodo tiene padre, y su valor es menor que el del padre
        if padre>0 and self.vector[indice][1]<self.vector[padre][1]:
            # Hace intercambio para arriba
            self.up_heapify(indice)
        # Si no
        else:
            # Hace intercambio para abajo
            self.down_heapify(indice)        
        
    # Reordena el diccionario de prioridad hacia arriba a partir del elemento
    # almacenado en la posicion indice
    def up_heapify(self,indice):
        # Si es la raíz del árbol, no hace nada.
        if indice == 0: 
            return
        # Saca el padre
        padre = self.nodopadre(indice)
        # Si el valor del índice es mayor que el del padre
        # se cumple la propiedad.  
        if (self.vector[indice][1]>=self.vector[padre][1]): 
            return 
        # Si no, hace el intercambio, y llama a la función 
        # recursiva con el padre.     
        else: 
            self.cambia_elementos(padre, indice)
            self.up_heapify(padre)
            return
    
    # Reordena el diccionario de prioridad hacia abajo a partir del elemento
    # almacenado en la posicion indice
    def down_heapify(self,indice):
        # Extrae los índices de los hijos.
        hijoIz = self.hijo_izquierdo(indice)
        hijoDe = self.hijo_derecho(indice)
        
        # Si el índice del hijo izquierdo es mayor que el tamaño es que
        # no tiene hijos, y vuelve.
        if hijoIz>self.tamano:
            return
        # Si no tiene hijo derecho, o el valor del hijo izquierdo es menor, entonces
        # el hijo a considerar es el izquierdo
        if hijoDe>self.tamano or (self.vector[hijoIz][1] < self.vector[hijoDe][1]):
            hijo = hijoIz
        # Si tiene hijo derecho y el hijo izquierdo no es menor, entonces utiliza el
        # derecho.    
        else:
            hijo = hijoDe
        
        # Si el valor del hijo es menor que el del padre
        # intercambia y llama a la función recursiva con el hijo.
        if self.vector[hijo][1] < self.vector[indice][1]:
            self.cambia_elementos(indice, hijo)
            self.down_heapify(hijo)
            return
   
    
    # Intercambia dos elementos (han de ser padre e hijo)
    def cambia_elementos(self, nodo1, nodo2):
        # Cambia los valores en el diccionario. 
        self.diccionario[self.vector[nodo1][0]] = nodo2
        self.diccionario[self.vector[nodo2][0]] = nodo1
        # Cambia los valores en el vector
        self.vector[nodo2],self.vector[nodo1] = self.vector[nodo1],self.vector[nodo2]        
       
         
    # Devuelve la posición del padre del elemento almacenado en la posición
    # indice del vector    
    def nodopadre(self,indice):    
        if (indice%2==0):  
            return int((indice-2) / 2) # Hijo derecho
        else:  
            return int((indice-1) / 2) # Hijo izquierdo
    
    # Devuelve la posición del hijo izquierdo del elemento almacenado en la 
    # posición indice del vector        
    def hijo_izquierdo(self,indice): 
        return 2*indice+1
    
    # Devuelve la posición del hijo izquierdo del elemento almacenado en la 
    # posición indice del vector        
    def hijo_derecho(self,indice): 
        return 2*indice+2  
      
    # Devuelve True si el elemento almacenado en la posición indice es una 
    # hoja del árbol.  
    def es_hoja(self,indice): 
        return (self.__hijo_izquierdo(indice) >= self.tamano) and (self.__hijo_derecho(indice) >= self.tamano)
    
    # Devuelve True si el elemento almacenado en la posición indice tiene
    # solamente un hijo.
    
    def un_hijo(self,indice): 
        return (self.__hijo_izquierdo(indice) < self.tamano) and (self.__hijo_derecho(indice) >= self.tamano)
        
        
    # Con estas funciones se premite llamar al diccionario de prioridad como a cualquier
    # otra secuencia    
        
    # Devuelve el valor de un elemento
    # Si dp es un diccionario de prioridad, se puede utilizar 'dp[elemento]'
    def __getitem__(self,elemento):
        indice = self.diccionario[elemento]
        return self.vector[indice][1]   
    
    # Devuelve True si el diccionario contiene el elemento.
    # Si dp es un diccionario de prioridad, se puede usar 'elemento in dp'
    def __contains__(self,elemento):  
        return elemento in self.diccionario   
    
    # Esta función permite actualizar directamente el valor de un elemento
    # Si dp es un diccionario de prioridad, se puede hacer 'dp[elemento]=valor'
    def __setitem__(self, elemento, valor):
        if elemento in self.diccionario:
            self.actualiza((elemento, valor))  
        else:
            self.inserta((elemento, valor))
        
    # Esta función permite actualizar directamente el valor de un elemento
    # Si dp es un diccionario de prioridad, se puede hacer 'del dp[elemento]'        
    def __delitem__(self,elemento):      
        self.borra(elemento)

# %% [markdown]
# En la siguiente celda tenemos un test, que debe dar el resultado siguiente:
#
# ('C', 3.7)
#
# 7.2
#
# 3
#
# True
#
# False
#
# ('H', 1)
#
# 3.14

# %%
# Esta función permite comprobar el funcionamiento del diccionario de prioridad.        
def test():
        L = [('A',6.5), ('B',4.3), ('C',3.7), ('D',5.8), ('E',9.1), ('F',7.2), ('G',7)]       
        # Creamos el diccionario de prioridad con la lista
        dp = dicPrioridad(L)
        print(dp.extrae_min())
        dp.inserta(('H', 1))
        print(dp['F'])
        dp.actualiza(('F',3))
        print(dp['F'])
        print('F' in dp)
        del dp['F']
        print('F' in dp)
        print(dp.extrae_min())
        dp['X'] = 3.14
        print(dp['X'])

test()
# Out:
# ('C', 3.7)
# 7.2
# 3
# True
# False
# ('H', 1)
# 3.14

# %% [markdown]
# En la siguiente celda se implementará el algoritmo de Dijkstra haciendo udo de la cola con prioridad. Para ello, se sustituirá la lista D de distancias al origen de los nodos candidatos y solución por la cola DP con la misma funcionalidad. No se hará ningún otro cambio más.

# %%
# Algoritmo 2
# Esta función debe implementar el algoritmo de Dijkstra con diccionario de prioridad
#
def dijkstra2(origen,destino):

    S = set([]) # Nodos incluidos
    Q = set([]) # Nodos candidatos
    DP = dicPrioridad() # Distancia al origen, implementada como diccionario de prioridad
    P = {} # Camino

    edges = list(dist.keys())
    
    # Estas estructuras almacenan los resultados  
    nodosVisitados = set([])
    aristasVisitadas = set([])
    camino = []
    TiempoViaje = 0  # Distancia al origen
    for i in ciudades:
       DP.__setitem__(i, math.inf)
    S.add(origen)
    DP.__setitem__(origen,0)
    ultimo = origen

    while ultimo!=destino:            
    # Extrae los nuevos candidatos
        busca = [v for (u,v) in edges if u==ultimo]

        # print(busca) (Descomentar para ver el formato de la lista de sucesores)

        # Aquí debe completarse el algoritmo de Dijkstra sobre la base 
        # de la diapositiva 49 del tema 1
        # NOTA: Ahoa DP es un lista con prioridad
        ul=ultimo
        for i in busca:
            if i not in S:
                aristasVisitadas.add((ul,i))
                Q.add(i)
                nodosVisitados.add(i)
                if DP.__getitem__(ul)+dist[(ul,i)]<DP.__getitem__(i):
                   DP.__setitem__(i,DP.__getitem__(ul)+dist[(ul,i)])
                   P[i]=ul
                   ultimo=i
        # min=math.inf
        # for (i,j) in list(DP.items()): #SÚPER INEFICIENTE
        #     if i in Q:
        #         if j<min:
        #             min = j
        #             min_i = i
        # min_i

        DP_copy = dicPrioridad(DP.vector)
        DP_copy.diccionario = {i:j for i,j in DP.diccionario.items() if i in Q}
        #del(DP_copy.diccionario[ultimo])
        ultimo = DP_copy.extrae_min()[0]
        if ultimo in Q:
            Q.remove(ultimo)
        # for i in range (0,len(Q)):
        #     if Q[i]==ultimo:
        #         Q.pop(i)
        #         break
        S.add(ultimo)
    # Aquí ya ha salido del bucle
        # Busca el mejor candidato 
        # Esta acción es logarítmica en el tamaño de Q
        #
        # item = (ultimo,distancia)  
        #
        #item = DP.extrae_min()
        #ultimo = item[0]
    TiempoViaje = ultimo[1]
   
        # Lo incorpora
        #Q.remove(ultimo)
        #S.add(ultimo)
                    
    # Aquí ya ha salido del bucle
    # TiempoViaje se mantiene como la distancia al último
        
    # Recupera el camino
    d = destino
    o = P[d]
    camino.append((d,o))
    while o != origen:
        d = o
        o = P[d]
        camino.append((d,o))               
        
        # Devuelve la salida.
    return (TiempoViaje, Q | S,  aristasVisitadas, camino)

# %%
#
# Mapa para la salida de Dijkstra 2
#

salida2 = folium.Map(location = [lat/tam, long/tam], zoom_start=6)
for i in capitales:
    folium.Marker(
        location=[capitales[i][0] , capitales[i][1]],
        #icon=folium.Icon(color = 'red'),
        icon=folium.DivIcon(html=f"""
            <div><svg>
                <rect x="0", y="0" width="5" height="5", fill="black", opacity=".5" />
            </svg></div>"""),
        popup=''
    ).add_to(salida2)

# %%
# Prueba
Origen = 'Albacete'
Destino = 'Vigo'

t=time()
Ans2 = dijkstra2(Origen, Destino)
t=time()-t

print('El tiempo de viaje es ', Ans2[0])
print('Número de nodos: ', len(Ans2[3]))
print('El tiempo de cómputo es ', t)
print('Aristas estudiadas: ', len(Ans2[2]))

# Dibujar una línea negra entre los puntos candidatos
folium.Marker(
    location=[ciudades[Origen][0] , ciudades[Origen][1]],
    #icon=folium.Icon(color = 'red'),
    icon=folium.DivIcon(html=f"""
        <div><svg>
            <rect x="0", y="0" width="10" height="10", fill="red", opacity=".8" />
        </svg></div>"""),
    popup=''
).add_to(salida2)
folium.Marker(
    location=[ciudades[Destino][0] , ciudades[Destino][1]],
    #icon=folium.Icon(color = 'red'),
    icon=folium.DivIcon(html=f"""
        <div><svg>
            <rect x="0", y="0" width="10" height="10", fill="red", opacity=".8" />
        </svg></div>"""),
    popup=''
).add_to(salida2)
    
for arista in Ans2[2]:
    linea = folium.PolyLine(locations=[ciudades[arista[0]], ciudades[arista[1]]],
                        color='black', weight=2, opacity=0.5).add_to(salida2)
for arista in Ans2[3]:
    linea = folium.PolyLine(locations=[ciudades[arista[0]], ciudades[arista[1]]],
                        color='red', weight=5, opacity=0.8).add_to(salida2)    
salida2
# Out:
# El tiempo de viaje es  i
# Número de nodos:  15
# El tiempo de cómputo es  75.821293592453
# Aristas estudiadas:  550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d87b5fb3e8a67bb53bc75ef614500077 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d87b5fb3e8a67bb53bc75ef614500077&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d87b5fb3e8a67bb53bc75ef614500077 = L.map(
#                 &quot;map_d87b5fb3e8a67bb53bc75ef614500077&quot;,
#                 {
#                     center: [40.61331950370985, -3.5532346331037137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ea4d0206e6777e192719249bb040333 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ea4d0206e6777e192719249bb040333.addTo(map_d87b5fb3e8a67bb53bc75ef614500077);
#
#
#             var marker_2b8dc0d47c89ae8126ef91844259e569 = L.marker(
#                 [43.37012643, -8.39114853],
#                 {
# }
#             ).addTo(map_d87b5fb3e8a67bb53bc75ef614500077);
#
#
#             var div_icon_987893f2b695cddd0e7b967c766ed823 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_2b8dc0d47c89ae8126ef91844259e569.setIcon(div_icon_987893f2b695cddd0e7b967c766ed823);
#
#
#         var popup_23ba62623bd3e1711f0d889d881345cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3c2eb2c670fe35ac26330fd8d1a2bd9 = $(`&lt;div id=&quot;html_f3c2eb2c670fe35ac26330fd8d1a2bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_23ba62623bd3e1711f0d889d881345cf.setContent(html_f3c2eb2c670fe35ac26330fd8d1a2bd9);
#
#
#
#         marker_2b8dc0d47c89ae8126ef91844259e569.bindPopup(popup_23ba62623bd3e1711f0d889d881345cf)
#         ;
#
#
#
#
#                 marker_2b8dc0d47c89ae8126ef91844259e569.setIcon(div_icon_987893f2b695cddd0e7b967c766ed823);
#
#
#             var marker_f6fbd7044adc6b9645d7ba34d6c4a344 = L.marker(
#                 [38.99588053, -1.85574745],
#                 {
# }
#             ).addTo(map_d87b5fb3e8a67bb53bc75ef614500077);
#
#
#             var div_icon_0b5b666d3fec0ee183d01c9c8fc8a16e = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_f6fbd7044adc6b9645d7ba34d6c4a344.setIcon(div_icon_0b5b666d3fec0ee183d01c9c8fc8a16e);
#
#
#         var popup_f2b2481673208b6d5e54a785978ee328 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eb5d6432fd53bf1e23f70c706da7a6c = $(`&lt;div id=&quot;html_4eb5d6432fd53bf1e23f70c706da7a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_f2b2481673208b6d5e54a785978ee328.setContent(html_4eb5d6432fd53bf1e23f70c706da7a6c);
#
#
#
#         marker_f6fbd7044adc6b9645d7ba34d6c4a344.bindPopup(popup_f2b2481673208b6d5e54a785978ee328)
#         ;
#
#
#
#
#                 marker_f6fbd7044adc6b9645d7ba34d6c4a344.setIcon(div_icon_0b5b666d3fec0ee183d01c9c8fc8a16e);
#
#
#             var marker_912109289fbe7a9b81ffffec4e75bfda = L.marker(
#                 [38.34548705, -0.4831832],
#                 {
# }
#             ).addTo(map_d87b5fb3e8a67bb53bc75ef614500077);
#
#
#             var div_icon_d2b2f18afcab2c6c182061f58e7410e2 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_912109289fbe7a9b81ffffec4e75bfda.setIcon(div_icon_d2b2f18afcab2c6c182061f58e7410e2);
#
#
#         var popup_5e4f131790a181b2a01c2e1a0bd9c516 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c121d7054392d2064f02a845c964336 = $(`&lt;div id=&quot;html_9c121d7054392d2064f02a845c964336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_5e4f131790a181b2a01c2e1a0bd9c516.setContent(html_9c121d7054392d2064f02a845c964336);
#
#
#
#         ma

# %% [markdown]
# El resultado de dijkstra2 debe ser, en casi todo, igual a dijkstra1, salvo en el tiempo de ejecución. No obstante, los cambios deben ser poco significativos debido al pequeño tamaño, en número de nodos y aristas, del grafo estudiado.

# %% [markdown]
# Estudiamos, por último, una tercera versión, que se estudiará más en detalle en el tema 6, de algoritmos de ramificación y poda para comprender su funcionamiento.
#
# Se trata de una poda eucídea, y para ello haremos uso del paquete geopy que nos proporcionará la distancia euclídea entre dos puntos de la esfera terrestre.
#
# La variante será considerar que todas las distancias parciales, desde el origen hasta un nodo candidato, se incrementarán con la distancia euclídea desde el candidato hasta el destino. Para ello, se considerará que existe una autopista imaginaria desde dicho candidato hasta el destino que se puede recorrer a 120 km/h. Eso permitirá que los nodos alejados, a los que se les añade esta distancia imaginaria, serán descartados frente a los nodos más cercanos.
#
# Por ahora, esta idea es una mera heurística que funciona, aunque volvemos a repetir que se estudiará en detalle su fundamento en el tema 6.

# %%
# Algoritmo 3
# Esta función debe implementar el algoritmo de Dijkstra con diccionario de prioridad y distancia euclídea
#
import geopy.distance


def dijkstra3(origen,destino):

    S = set([]) # Nodos incluidos
    Q = set([]) # Nodos candidatos
    DP = dicPrioridad() # Distancia al origen, implementada como diccionario de prioridad
    P = {}      # Camino
    EU = {}     # Distancias euclídeas

    edges = list(dist.keys())
    dicCarreteras
    dicAutovias
    # Estas estructuras almacenan los resultados  
    nodosVisitados = set([])
    aristasVisitadas = set([])
    camino = []
    TiempoViaje = 0  # Distancia al origen
    for i in ciudades:
       DP.__setitem__(i, math.inf)
    for i in ciudades:
        for j in ciudades:
            elem = (i,j)
            EU[(i,j)] = geopy.distance.distance()
    S.add(origen)
    DP.__setitem__(origen,0)
    ultimo = origen

    while ultimo!=destino:            
    # Extrae los nuevos candidatos
        busca = [v for (u,v) in edges if u==ultimo]

        ul=ultimo
        for i in busca:
            if i not in S:
                aristasVisitadas.add((ul,i))
                Q.add(i)
                nodosVisitados.add(i)
                if (i,destino) not in EU:
                    EU[(i,destino)] = geopy.distance.distance()
                if DP.__getitem__(ul)+dist[(ul,i)]<DP.__getitem__(i):
                   DP.__setitem__(i,DP.__getitem__(ul)+dist[(ul,i)])
                   P[i]=ul
                   ultimo=i
        # min=math.inf
        # for (i,j) in list(DP.items()): #SÚPER INEFICIENTE
        #     if i in Q:
        #         if j<min:
        #             min = j
        #             min_i = i
        # min_i

        DP_copy = dicPrioridad(DP.vector)
        DP_copy.diccionario = {i:j for i,j in DP.diccionario.items() if i in Q}
        #del(DP_copy.diccionario[ultimo])
        ultimo = DP_copy.extrae_min()[0]
        if ultimo in Q:
            Q.remove(ultimo)
        # for i in range (0,len(Q)):
        #     if Q[i]==ultimo:
        #         Q.pop(i)
        #         break
        S.add(ultimo)
    # Aquí ya ha salido del bucle
        # Busca el mejor candidato 
        # Esta acción es logarítmica en el tamaño de Q
        #
        # item = (ultimo,distancia)  
        #
        #item = DP.extrae_min()
        #ultimo = item[0]
    TiempoViaje = ultimo[1]
                    
    # Aquí ya ha salido del bucle
    # TiempoViaje se mantiene como la distancia al último
        
    # Recupera el camino
    d = destino
    o = P[d]
    camino.append((d,o))
    while o != origen:
        d = o
        o = P[d]
        camino.append((d,o))               
        
        # Devuelve la salida.
    return (TiempoViaje, Q | S,  aristasVisitadas, camino)

# %%
#
# Mapa para la salida de Dijkstra 3
#

salida3 = folium.Map(location = [lat/tam, long/tam], zoom_start=6)
for i in capitales:
    folium.Marker(
        location=[capitales[i][0] , capitales[i][1]],
        #icon=folium.Icon(color = 'red'),
        icon=folium.DivIcon(html=f"""
            <div><svg>
                <rect x="0", y="0" width="5" height="5", fill="black", opacity=".5" />
            </svg></div>"""),
        popup=''
    ).add_to(salida3)

# %%
dicAutovias
# Out:
# {('Albacete', 'Almansa'): 57.257,
#  ('Adanero', 'San Rafael'): 39.312,
#  ('Adanero', 'Benavente'): 39.312,
#  ('Ágreda', 'Soria'): 36.5,
#  ('Alcalá de Henares', 'Guadalajara'): 31.348,
#  ('Alcantarilla', 'Callosa del Segura'): 32.417,
#  ('Alcantarilla', 'Cieza'): 36.059,
#  ('Alcantarilla', 'Totana'): 24.863,
#  ('Alcañiz', 'Híjar'): 25.54,
#  ('Alcañiz', 'Reus'): 85.929,
#  ('Alcolea del Pinar', 'Molina de Aragón'): 55.595,
#  ('Alcoy', "Sant Joan d'Alacant"): 27.778,
#  ('Alfaro', 'Ágreda'): 35.553,
#  ('Alfaro', 'Tafalla'): 29.2,
#  ('Algeciras', 'Tarifa'): 15.52,
#  ('Almansa', 'Xàtiva'): 64.0,
#  ('Almadrones', 'Alcolea del Pinar'): 29.563,
#  ('Almería', 'Adra'): 41.808,
#  ('Alzira', 'Silla'): 25.204,
#  ('Alzira', 'Xàtiva'): 21.258,
#  ('Amposta', 'Vinarós'): 26.842,
#  ('Aranjuez', 'Madrid'): 34.704,
#  ('Aranjuez', 'Ocaña'): 15.792,
#  ('Arévalo', 'Adanero'): 19.479,
#  ('Arganda del Rey', 'Tarancón'): 37.876,
#  ('Armiñón', 'Miranda del Ebro'): 17.026,
#  ('Astorga', 'La Bañeza'): 28.796,
#  ('Astorga', 'Ponferrada'): 33.612,
#  ('Baamonde', 'Becerrea'): 50.597,
#  ('Baamonde', 'Betanzos'): 28.084,
#  ('Badajoz', 'Mérida'): 50.174,
#  ('Barcelona', 'Mataró'): 19.642,
#  ('Basauri', 'Armiñón'): 49.661,
#  ('Basauri', 'Bilbao'): 7.445,
#  ('Béjar', 'Salamanca'): 43.897,
#  ('Benavente', 'Astorga'): 70.0,
#  ('Benicarló', 'Vinarós'): 8.513,
#  ('Benicàssim', 'Castelló de la Plana'): 7.3,
#  ('Benicàssim', 'Torreblanca'): 15.52,
#  ('Betanzos', 'A Coruña'): 23.542,
#  ('Burgo de Osma', 'Soria'): 48.357,
#  ('Burgos', 'Lerma'): 32.12,
#  ('Cáceres', 'Plasencia'): 63.657,
#  ('Castelldefels', 'Barcelona'): 19.036,
#  ('Castelldefels', 'Sitges'): 23.965833,
#  ('Castelló de la Plana', 'Sagunt'): 52.0,
#  ('Castelló de la Plana', 'Vinarós'): 80.0,
#  ('Ciudad Real', 'Puertollano'): 28.348,
#  ('Cocentaina', 'Alcoy'): 7.445,
#  ('Collado Villalba', 'Madrid'): 29.2,
#  ('Córdoba', 'Montoro'): 29.563,
#  ('Córdoba', 'Sevilla'): 106.325,
#  ('Cuenca', 'Cañete'): 48.379,
#  ('Dos Hermanas', 'Jerez de la Frontera'): 60.197,
#  ('El Burgo del Ebro', 'Zaragoza'): 18.353333,
#  ('Elx', 'Alacant'): 14.673,
#  ('Elx', 'Callosa del Segura'): 24.115556,
#  ('Estepona', 'Guadiaro'): 28.377778,
#  ('Fuengirola', 'Marbella'): 14.6,
#  ('Fuengirola', 'Torremolinos'): 16.518,
#  ('Guadalajara', 'Almadrones'): 26.321,
#  ('Guadiaro', 'Algeciras'): 21.764444,
#  ('Hellín', 'Albacete'): 57.257,
#  ('Hellín', 'Cieza'): 23.085,
#  ('Híjar', 'El Burgo del Ebro'): 50.68,
#  ('Jabugo', 'Valverde del Camino'): 35.688889,
#  ('Jerez de la Frontera', 'Puerto Real'): 24.387778,
#  ('La Albuera', 'Badajoz'): 22.806,
#  ('La Albuera', 'Jabugo'): 82.733333,
#  ('La Bañeza', 'Benavente'): 36.059,
#  ('La Roda', 'Albacete'): 27.547,
#  ('Lerma', 'Aranda de Duero'): 36.964,
#  ("L'Hospitalet de l'Infant", 'Amposta'): 37.394,
#  ('Liria', 'Valencia'): 29.2,
#  ('Lorca', 'Puerto Lumbreras'): 12.389,
#  ('Lorca', 'Totana'): 15.304444,
#  ('Losa del Obispo', 'Cañete'): 49.64,
#  ('Losa del Obispo', 'Liria'): 26.321,
#  ('Los Gallardos', 'Almería'): 58.927,
#  ('Los Gallardos', 'Vera'): 13.765556,
#  ('Madrid', 'Adanero'): 110.0,
#  ('Madrid', 'Alcalá de Henares'): 24.948,
#  ('Madrid', 'Arganda del Rey'): 26.321,
#  ('Madrid', 'Maqueda'): 59.592,
#  ('Albacete', 'Tarancón'): 88.4,
#  ('Madrid', 'Toledo'): 56.186,
#  ('Madrid', 'Venturada'): 36.529,
#  ('Málaga', 'Torremolinos'): 10.26,
#  ('Maqueda', 'Talavera de la Reina'): 35.101,
#  ('Marbella', 'Estepona'): 28.331111,
#  ('Mataró', 'Girona'): 54.315,
#  ('Medina del Campo', 'Arévalo'): 24.777,
#  ('Medina del Campo', 'Tordesillas'): 23.767,
#  ('Mérida', 'Badajoz'): 50.174,
#  ('Mérida', 'Cáceres'): 64.97,
#  ('Miranda del Ebro', 'Armiñón'): 17.026,
#  ('Miranda del Ebro', 'Burgos'): 50.618,
#  ('Monreal del Campo', 'Molina de Aragón'): 31.517,
#  ('Montalbán', 'Alcañiz'): 57.85,
#  ('Montalbán', 'Monreal del Campo'): 35.282,
#  ('Motril', 'Adra'): 36.529,
#  ('Motril', 'Almuñecar'): 19.203,
#  ('Murcia', 'Alcantarilla'): 10.324,
#  ('Navalmoral de la Mata', 'Talavera de la Reina'): 53.065,
#  ('Nules', 'Sagunt'): 31.995556,
#  ('Nules', 'Vila-real'): 6.529,
#  ('Ocaña', 'Villarrobledo'): 88.242,
#  ('Peñíscola', 'Benicarló'): 5.84,
#  ('Peñíscola', 'Torreblanca'): 10.387778,
#  ('Plasencia', 'Béjar'): 39.176,
#  ('Ponferrada', 'Becerrea'): 49.079,
#  ('Ponteareas', 'Ribadavia'): 49.079,
#  ('Puertollano', 'Montoro'): 72.502,
#  ('Puerto Lumbreras', 'Vera'): 29.09,
#  ('Puerto Real', 'Cádiz'): 14.673,
#  ('Reus', 'Alcañiz'): 71.6075,
#  ('Reus', 'Tarragona'): 18.059,
#  ('Ribadavia', 'Vigo'): 68.0,
#  ('Riaza', 'San Esteban de Gormaz'): 32.417,
#  ('Riaza', 'Venturada'): 52.924,
#  ('Rincón de la Victorio', 'Almuñecar'): 40.906,
#  ('Rincón de la Victorio', 'Málaga'): 21.151111,
#  ('San Esteban de Gormaz', 'Burgo de Osma'): 13.461,
#  ('San Fernando', 'Cádiz'): 10.324,
#  ('San Fernando', 'Chiclana de la Frontera'): 11.403,
#  ('San Rafael', 'Collado Villalba'): 17.822,
#  ("Sant Joan d'Alacant", 'Alacant'): 6.529,
#  ('Sevilla', 'Dos Hermanas'): 13.774,
#  ('Sevilla', 'Huelva'): 76.605,
#  ('Sitges', 'Castelldefels'): 28.759,
#  ('Sitges', 'Tarragona'): 28.684,
#  ('Tafalla', 'Pamplona'): 26.321,
#  ('Tarancón', 'Cuenca'): 55.499,
#  ('Tarancón', 'Madrid'): 86.0,
#  ('Tarifa', 'Chiclana de la Frontera'): 46.468,
#  ('Tarragona', "L'Hospitalet de l'Infant"): 24.299,
#  ('Tarragona', 'Reus'): 15.049167,
#  ('Tarragona', 'Sitges'): 28.684,
#  ('Toledo', 'Ciudad Real'): 85.294,
#  ('Tordesillas', 'Benavente'): 67.176,
#  ('Trujillo', 'Mérida'): 70.957,
#  ('Trujillo', 'Navalmoral de la Mata'): 41.321,
#  ('Valencia', 'Sagunt'): 21.056,
#  ('Valencia', 'Silla'): 11.119,
#  ('Valverde del Camino', 'Huelva'): 33.612,
#  ('Venturada', 'Aranda de Duero'): 87.612,
#  ('Vila-real', 'Castelló de la Plana'): 9.234,
#  ('Villarrobledo', 'La Roda'): 37.223,
#  ('Xàtiva', 'Cocentaina'): 23.542,
#  ('Xàtiva', 'Silla'): 50.0,
#  ('Zamora', 'Salamanca'): 68.306667}

# %%
{i:j for (i,j) in dicAutovias}
# Out:
# {'Albacete': 'Tarancón',
#  'Adanero': 'Benavente',
#  'Ágreda': 'Soria',
#  'Alcalá de Henares': 'Guadalajara',
#  'Alcantarilla': 'Totana',
#  'Alcañiz': 'Reus',
#  'Alcolea del Pinar': 'Molina de Aragón',
#  'Alcoy': "Sant Joan d'Alacant",
#  'Alfaro': 'Tafalla',
#  'Algeciras': 'Tarifa',
#  'Almansa': 'Xàtiva',
#  'Almadrones': 'Alcolea del Pinar',
#  'Almería': 'Adra',
#  'Alzira': 'Xàtiva',
#  'Amposta': 'Vinarós',
#  'Aranjuez': 'Ocaña',
#  'Arévalo': 'Adanero',
#  'Arganda del Rey': 'Tarancón',
#  'Armiñón': 'Miranda del Ebro',
#  'Astorga': 'Ponferrada',
#  'Baamonde': 'Betanzos',
#  'Badajoz': 'Mérida',
#  'Barcelona': 'Mataró',
#  'Basauri': 'Bilbao',
#  'Béjar': 'Salamanca',
#  'Benavente': 'Astorga',
#  'Benicarló': 'Vinarós',
#  'Benicàssim': 'Torreblanca',
#  'Betanzos': 'A Coruña',
#  'Burgo de Osma': 'Soria',
#  'Burgos': 'Lerma',
#  'Cáceres': 'Plasencia',
#  'Castelldefels': 'Sitges',
#  'Castelló de la Plana': 'Vinarós',
#  'Ciudad Real': 'Puertollano',
#  'Cocentaina': 'Alcoy',
#  'Collado Villalba': 'Madrid',
#  'Córdoba': 'Sevilla',
#  'Cuenca': 'Cañete',
#  'Dos Hermanas': 'Jerez de la Frontera',
#  'El Burgo del Ebro': 'Zaragoza',
#  'Elx': 'Callosa del Segura',
#  'Estepona': 'Guadiaro',
#  'Fuengirola': 'Torremolinos',
#  'Guadalajara': 'Almadrones',
#  'Guadiaro': 'Algeciras',
#  'Hellín': 'Cieza',
#  'Híjar': 'El Burgo del Ebro',
#  'Jabugo': 'Valverde del Camino',
#  'Jerez de la Frontera': 'Puerto Real',
#  'La Albuera': 'Jabugo',
#  'La Bañeza': 'Benavente',
#  'La Roda': 'Albacete',
#  'Lerma': 'Aranda de Duero',
#  "L'Hospitalet de l'Infant": 'Amposta',
#  'Liria': 'Valencia',
#  'Lorca': 'Totana',
#  'Losa del Obispo': 'Liria',
#  'Los Gallardos': 'Vera',
#  'Madrid': 'Venturada',
#  'Málaga': 'Torremolinos',
#  'Maqueda': 'Talavera de la Reina',
#  'Marbella': 'Estepona',
#  'Mataró': 'Girona',
#  'Medina del Campo': 'Tordesillas',
#  'Mérida': 'Cáceres',
#  'Miranda del Ebro': 'Burgos',
#  'Monreal del Campo': 'Molina de Aragón',
#  'Montalbán': 'Monreal del Campo',
#  'Motril': 'Almuñecar',
#  'Murcia': 'Alcantarilla',
#  'Navalmoral de la Mata': 'Talavera de la Reina',
#  'Nules': 'Vila-real',
#  'Ocaña': 'Villarrobledo',
#  'Peñíscola': 'Torreblanca',
#  'Plasencia': 'Béjar',
#  'Ponferrada': 'Becerrea',
#  'Ponteareas': 'Ribadavia',
#  'Puertollano': 'Montoro',
#  'Puerto Lumbreras': 'Vera',
#  'Puerto Real': 'Cádiz',
#  'Reus': 'Tarragona',
#  'Ribadavia': 'Vigo',
#  'Riaza': 'Venturada',
#  'Rincón de la Victorio': 'Málaga',
#  'San Esteban de Gormaz': 'Burgo de Osma',
#  'San Fernando': 'Chiclana de la Frontera',
#  'San Rafael': 'Collado Villalba',
#  "Sant Joan d'Alacant": 'Alacant',
#  'Sevilla': 'Huelva',
#  'Sitges': 'Tarragona',
#  'Tafalla': 'Pamplona',
#  'Tarancón': 'Madrid',
#  'Tarifa': 'Chiclana de la Frontera',
#  'Tarragona': 'Sitges',
#  'Toledo': 'Ciudad Real',
#  'Tordesillas': 'Benavente',
#  'Trujillo': 'Navalmoral de la Mata',
#  'Valencia': 'Silla',
#  'Valverde del Camino': 'Huelva',
#  'Venturada': 'Aranda de Duero',
#  'Vila-real': 'Castelló de la Plana',
#  'Villarrobledo': 'La Roda',
#  'Xàtiva': 'Silla',
#  'Zamora': 'Salamanca'}

# %%
# Prueba 3
Origen = 'Albacete'
Destino = 'Vigo'

t=time()
Ans3 = dijkstra3(Origen, Destino)
t=time()-t

print('El tiempo de viaje es ', Ans3[0])
print('Número de nodos: ', len(Ans3[3]))
print('El tiempo de cómputo es ', t)
print('Aristas estudiadas: ', len(Ans3[2]))

# Dibujar una línea negra entre los puntos candidatos
folium.Marker(
    location=[ciudades[Origen][0] , ciudades[Origen][1]],
    #icon=folium.Icon(color = 'red'),
    icon=folium.DivIcon(html=f"""
        <div><svg>
            <rect x="0", y="0" width="10" height="10", fill="red", opacity=".8" />
        </svg></div>"""),
    popup=''
).add_to(salida3)
folium.Marker(
    location=[ciudades[Destino][0] , ciudades[Destino][1]],
    #icon=folium.Icon(color = 'red'),
    icon=folium.DivIcon(html=f"""
        <div><svg>
            <rect x="0", y="0" width="10" height="10", fill="red", opacity=".8" />
        </svg></div>"""),
    popup=''
).add_to(salida3)
    
for arista in Ans3[2]:
    linea = folium.PolyLine(locations=[ciudades[arista[0]], ciudades[arista[1]]],
                        color='black', weight=2, opacity=0.5).add_to(salida3)
for arista in Ans3[3]:
    linea = folium.PolyLine(locations=[ciudades[arista[0]], ciudades[arista[1]]],
                        color='red', weight=5, opacity=0.8).add_to(salida3)    
salida3
# Out:
# El tiempo de viaje es  i
# Número de nodos:  15
# El tiempo de cómputo es  65.37942481040955
# Aristas estudiadas:  550
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c1de13be287ad2b79ada5bac190e3b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c1de13be287ad2b79ada5bac190e3b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c1de13be287ad2b79ada5bac190e3b4 = L.map(
#                 &quot;map_3c1de13be287ad2b79ada5bac190e3b4&quot;,
#                 {
#                     center: [40.61331950370985, -3.5532346331037137],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_587aa82dae2b8e2d1354c8e1efa5c552 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_587aa82dae2b8e2d1354c8e1efa5c552.addTo(map_3c1de13be287ad2b79ada5bac190e3b4);
#
#
#             var marker_f7c174fa1441140f4b0151bfe29f9ce1 = L.marker(
#                 [43.37012643, -8.39114853],
#                 {
# }
#             ).addTo(map_3c1de13be287ad2b79ada5bac190e3b4);
#
#
#             var div_icon_abb1a094906b8c79ea04fb41d3fbb404 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_f7c174fa1441140f4b0151bfe29f9ce1.setIcon(div_icon_abb1a094906b8c79ea04fb41d3fbb404);
#
#
#         var popup_20f2ee856493c59bbdd8c67963e55cd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d3859209388b88426a5648a8e72ecad = $(`&lt;div id=&quot;html_5d3859209388b88426a5648a8e72ecad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_20f2ee856493c59bbdd8c67963e55cd9.setContent(html_5d3859209388b88426a5648a8e72ecad);
#
#
#
#         marker_f7c174fa1441140f4b0151bfe29f9ce1.bindPopup(popup_20f2ee856493c59bbdd8c67963e55cd9)
#         ;
#
#
#
#
#                 marker_f7c174fa1441140f4b0151bfe29f9ce1.setIcon(div_icon_abb1a094906b8c79ea04fb41d3fbb404);
#
#
#             var marker_83c6446059b5ac92ebde1b629d7a6df5 = L.marker(
#                 [38.99588053, -1.85574745],
#                 {
# }
#             ).addTo(map_3c1de13be287ad2b79ada5bac190e3b4);
#
#
#             var div_icon_e3cc77edd05e65bfc99fb7d919947720 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_83c6446059b5ac92ebde1b629d7a6df5.setIcon(div_icon_e3cc77edd05e65bfc99fb7d919947720);
#
#
#         var popup_ec276e35a1dba45d91f98321668716c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2799cf836e67e4795ba9b20ad4db0b1 = $(`&lt;div id=&quot;html_c2799cf836e67e4795ba9b20ad4db0b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_ec276e35a1dba45d91f98321668716c8.setContent(html_c2799cf836e67e4795ba9b20ad4db0b1);
#
#
#
#         marker_83c6446059b5ac92ebde1b629d7a6df5.bindPopup(popup_ec276e35a1dba45d91f98321668716c8)
#         ;
#
#
#
#
#                 marker_83c6446059b5ac92ebde1b629d7a6df5.setIcon(div_icon_e3cc77edd05e65bfc99fb7d919947720);
#
#
#             var marker_dad1ff90e5c09976e6e517deb8fb14f8 = L.marker(
#                 [38.34548705, -0.4831832],
#                 {
# }
#             ).addTo(map_3c1de13be287ad2b79ada5bac190e3b4);
#
#
#             var div_icon_a723b6051f0d35142b88b0b72b6b73b7 = L.divIcon({
#   &quot;html&quot;: &quot;\n            \u003cdiv\u003e\u003csvg\u003e\n                \u003crect x=\&quot;0\&quot;, y=\&quot;0\&quot; width=\&quot;5\&quot; height=\&quot;5\&quot;, fill=\&quot;black\&quot;, opacity=\&quot;.5\&quot; /\u003e\n            \u003c/svg\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_dad1ff90e5c09976e6e517deb8fb14f8.setIcon(div_icon_a723b6051f0d35142b88b0b72b6b73b7);
#
#
#         var popup_84827fe2c65687986753687815c265fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1464713f8d31155fbc4fec18ecc3a64 = $(`&lt;div id=&quot;html_c1464713f8d31155fbc4fec18ecc3a64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_84827fe2c65687986753687815c265fe.setContent(html_c1464713f8d31155fbc4fec18ecc3a64);
#
#
#
#         ma

# %% [markdown]
# El tiempo de viaje calculado y el número de nodos debe ser el mismo, sin embargo el tiempo de cómputo y las aristas estudiadas deben reducirse.

# %% [markdown]
# ### CONCLUSIONES

# %% [markdown]
# Explica aquí las conclusiones
